# %% [markdown]
# # Load libraries

# %%
import cv2
import numpy as np
import pandas as pd

from keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint, TensorBoard
from keras.models import Model
from keras.layers import Input, concatenate, Conv2D, MaxPooling2D, Activation, UpSampling2D, BatchNormalization
from keras.optimizers import RMSprop
from keras.losses import binary_crossentropy
import keras.backend as K

from sklearn.model_selection import train_test_split

import matplotlib.pyplot as plt
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py:1067: UserWarning: Duplicate key in file "/home/ubuntu/.config/matplotlib/matplotlibrc", line #2
#   (fname, cnt))
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py:1067: UserWarning: Duplicate key in file "/home/ubuntu/.config/matplotlib/matplotlibrc", line #3
#   (fname, cnt))
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %% [markdown]
# # Define functions

# %%
def jaccard_coef(y_true, y_pred):
    y_true_fl = K.clip(K.batch_flatten(y_true), 0., 1.)
    y_pred_fl = K.clip(K.batch_flatten(y_pred), 0., 1.)
    y_true_fl = K.cast(K.greater(y_true_fl, 0.5), 'float32')
    y_pred_fl = K.cast(K.greater(y_pred_fl, 0.5), 'float32')
    intersection = K.sum(y_true_fl * y_pred_fl, axis=1)
    union = K.sum(K.maximum(y_true_fl, y_pred_fl), axis=1)
    union = K.switch(K.equal(union, 0), K.ones_like(union), union)
    return K.mean(intersection / K.cast(union, 'float32'))

def jaccard_coef_loss(y_true, y_pred):
    return -jaccard_coef(y_true, y_pred)

# %% [markdown]
# # Training

# %%
input_size = 224
max_epochs = 100
threshold  = 0.5

# %%
df_train = pd.read_csv('data2/data/train_masks.csv')

# %%
df_train.head()
# Out:
#                img camera_short_name camera_long_name  counter  suspect eye  \
# 0  G-TPC0001-R.jpg               TPC           Topcon        1        1   R
# 1  G-TPC0002-L.jpg               TPC           Topcon        2        1   L
# 2  G-TPC0003-L.jpg               TPC           Topcon        3        1   L
# 3  G-TPC0004-R.jpg               TPC           Topcon        4        1   R
# 4  G-TPC0005-L.jpg               TPC           Topcon        5        1   L
#
#    height  width  areaDisc  saturationPixels  saturationLevel  scale  g  b  \
# 0    1934   1956     70095                 0                0   1081  1  1
# 1    1934   1956     58620                 0                0   1081  1  1
# 2    1934   1956     58703              1100                0   1081  1  1
# 3    1934   1956     59826                 0                0   1081  1  1
# 4    1934   1956     50247                 0                0   1081  1  1
#
#    factor      M   P      C
# 0  0.9985  64.52  18  62.85
# 1  0.9985  64.52  18  62.85
# 2  0.9985  64.52  18  62.85
# 3  0.9985  64.52  18  62.85
# 4  0.9985  64.52  18  62.85

# %%
ids_train = df_train['img'].map(lambda s: s.split('.')[0])

# %%
ids_train_split, ids_valid_split = train_test_split(ids_train, test_size=0.2, random_state=42)

# %%
def randomHueSaturationValue(image, hue_shift_limit=(-180, 180),
                             sat_shift_limit=(-255, 255),
                             val_shift_limit=(-255, 255), u=0.5):
    if np.random.random() < u:
        image = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
        h, s, v = cv2.split(image)
        hue_shift = np.random.uniform(hue_shift_limit[0], hue_shift_limit[1])
        h = cv2.add(h, hue_shift)
        sat_shift = np.random.uniform(sat_shift_limit[0], sat_shift_limit[1])
        s = cv2.add(s, sat_shift)
        val_shift = np.random.uniform(val_shift_limit[0], val_shift_limit[1])
        v = cv2.add(v, val_shift)
        image = cv2.merge((h, s, v))
        image = cv2.cvtColor(image, cv2.COLOR_HSV2BGR)

    return image

# %%
def randomShiftScaleRotate(image, mask,
                           shift_limit=(-0.0625, 0.0625),
                           scale_limit=(-0.1, 0.1),
                           rotate_limit=(-45, 45), aspect_limit=(0, 0),
                           borderMode=cv2.BORDER_CONSTANT, u=0.5):
    if np.random.random() < u:
        height, width, channel = image.shape

        angle = np.random.uniform(rotate_limit[0], rotate_limit[1])  # degree
        scale = np.random.uniform(1 + scale_limit[0], 1 + scale_limit[1])
        aspect = np.random.uniform(1 + aspect_limit[0], 1 + aspect_limit[1])
        sx = scale * aspect / (aspect ** 0.5)
        sy = scale / (aspect ** 0.5)
        dx = round(np.random.uniform(shift_limit[0], shift_limit[1]) * width)
        dy = round(np.random.uniform(shift_limit[0], shift_limit[1]) * height)

        cc = np.math.cos(angle / 180 * np.math.pi) * sx
        ss = np.math.sin(angle / 180 * np.math.pi) * sy
        rotate_matrix = np.array([[cc, -ss], [ss, cc]])

        box0 = np.array([[0, 0], [width, 0], [width, height], [0, height], ])
        box1 = box0 - np.array([width / 2, height / 2])
        box1 = np.dot(box1, rotate_matrix.T) + np.array([width / 2 + dx, height / 2 + dy])

        box0 = box0.astype(np.float32)
        box1 = box1.astype(np.float32)
        mat = cv2.getPerspectiveTransform(box0, box1)
        image = cv2.warpPerspective(image, mat, (width, height), flags=cv2.INTER_LINEAR, borderMode=borderMode,
                                    borderValue=(
                                        0, 0,
                                        0,))
        mask = cv2.warpPerspective(mask, mat, (width, height), flags=cv2.INTER_LINEAR, borderMode=borderMode,
                                   borderValue=(
                                       0, 0,
                                       0,))

    return image, mask

# %%
def randomHorizontalFlip(image, mask, u=0.5):
    if np.random.random() < u:
        image = cv2.flip(image, 1)
        mask = cv2.flip(mask, 1)

    return image, mask

# %%
all_imgs  = {}
all_masks = {}
for id in ids_train:
    img  = cv2.imread('data2/data/train/{}.jpg'.format(id))
    img  = cv2.resize(img, (input_size, input_size))
    mask = cv2.imread('data2/data/train_masks/{}_mask.png'.format(id), cv2.IMREAD_GRAYSCALE)
    mask = cv2.resize(mask, (input_size, input_size))
    all_imgs[id]  = img
    all_masks[id] = mask

# %%
import random

# %%
def train_generator(train_batch_size):
    while True:
        this_ids_train_split = random.sample(list(ids_train_split), len(ids_train_split))
        for start in range(0, len(ids_train_split), train_batch_size):
            x_batch = []
            y_batch = []
            end = min(start + train_batch_size, len(ids_train_split))
            ids_train_batch = this_ids_train_split[start:end]
            for id in ids_train_batch:
                img  = all_imgs[id]
                mask = all_masks[id]
                img = randomHueSaturationValue(img,
                                               hue_shift_limit=(-50, 50),
                                               sat_shift_limit=(-5, 5),
                                               val_shift_limit=(-15, 15))
                img, mask = randomShiftScaleRotate(img, mask,
                                                   shift_limit=(-0.0625, 0.0625),
                                                   scale_limit=(-0.1, 0.1),
                                                   rotate_limit=(-0, 0))
                img, mask = randomHorizontalFlip(img, mask)
                mask = np.expand_dims(mask, axis=2)
                x_batch.append(img)
                y_batch.append(mask)
            x_batch = np.array(x_batch, np.float32) / 255
            y_batch = np.array(y_batch, np.float32) / 255
            yield x_batch, y_batch

# %%
def valid_generator(val_batch_size):
    while True:
        for start in range(0, len(ids_valid_split), val_batch_size):
            x_batch = []
            y_batch = []
            end = min(start + val_batch_size, len(ids_valid_split))
            ids_valid_batch = ids_valid_split[start:end]
            for id in ids_valid_batch.values:
                img  = all_imgs[id]
                mask = all_masks[id]
                mask = np.expand_dims(mask, axis=2)
                x_batch.append(img)
                y_batch.append(mask)
            x_batch = np.array(x_batch, np.float32) / 255
            y_batch = np.array(y_batch, np.float32) / 255
            yield x_batch, y_batch

# %%
train_batch_size = 3
val_batch_size   = 8

# %%
from zf_unet_224_model import ZF_UNET_224, dice_coef_loss, dice_coef
from keras.optimizers import Adam

model = ZF_UNET_224(weights='generator')
optim = Adam()
model.compile(optimizer=optim, loss=dice_coef_loss, metrics=[dice_coef, dice_coef_loss, jaccard_coef])

callbacks = [ModelCheckpoint(monitor='val_dice_coef_loss',
                             filepath='weights/best_zf_unet_224.h5',
                             save_best_only=True,
                             save_weights_only=True,
                             mode='max')]


history = model.fit_generator(generator=train_generator(train_batch_size),
                    steps_per_epoch=np.ceil(float(len(ids_train_split)) / float(train_batch_size)),
                    epochs=max_epochs,
                    verbose=2,
                    callbacks=callbacks,
                    validation_data=valid_generator(val_batch_size),
                    validation_steps=np.ceil(float(len(ids_valid_split)) / float(val_batch_size)))
# Out:
# Epoch 1/100
#  - 30s - loss: -5.9735e-01 - dice_coef: 0.5974 - dice_coef_loss: -5.9735e-01 - jaccard_coef: 0.4639 - val_loss: -6.9159e-01 - val_dice_coef: 0.6916 - val_dice_coef_loss: -6.9159e-01 - val_jaccard_coef: 0.5186
# Epoch 2/100
#  - 24s - loss: -7.9774e-01 - dice_coef: 0.7977 - dice_coef_loss: -7.9774e-01 - jaccard_coef: 0.6770 - val_loss: -8.1264e-01 - val_dice_coef: 0.8126 - val_dice_coef_loss: -8.1264e-01 - val_jaccard_coef: 0.6940
# Epoch 3/100
#  - 24s - loss: -8.4531e-01 - dice_coef: 0.8453 - dice_coef_loss: -8.4531e-01 - jaccard_coef: 0.7440 - val_loss: -8.4717e-01 - val_dice_coef: 0.8472 - val_dice_coef_loss: -8.4717e-01 - val_jaccard_coef: 0.7415
# Epoch 4/100
#  - 24s - loss: -8.6684e-01 - dice_coef: 0.8668 - dice_coef_loss: -8.6684e-01 - jaccard_coef: 0.7755 - val_loss: -8.9071e-01 - val_dice_coef: 0.8907 - val_dice_coef_loss: -8.9071e-01 - val_jaccard_coef: 0.8063
# Epoch 5/100
#  - 24s - loss: -8.8244e-01 - dice_coef: 0.8824 - dice_coef_loss: -8.8244e-01 - jaccard_coef: 0.7992 - val_loss: -9.0162e-01 - val_dice_coef: 0.9016 - val_dice_coef_loss: -9.0162e-01 - val_jaccard_coef: 0.8263
# Epoch 6/100
#  - 24s - loss: -8.8518e-01 - dice_coef: 0.8852 - dice_coef_loss: -8.8518e-01 - jaccard_coef: 0.8030 - val_loss: -8.8525e-01 - val_dice_coef: 0.8852 - val_dice_coef_loss: -8.8525e-01 - val_jaccard_coef: 0.7978
# Epoch 7/100
#  - 24s - loss: -8.8646e-01 - dice_coef: 0.8865 - dice_coef_loss: -8.8646e-01 - jaccard_coef: 0.8055 - val_loss: -9.0332e-01 - val_dice_coef: 0.9033 - val_dice_coef_loss: -9.0332e-01 - val_jaccard_coef: 0.8282
# Epoch 8/100
#  - 24s - loss: -8.9997e-01 - dice_coef: 0.9000 - dice_coef_loss: -8.9997e-01 - jaccard_coef: 0.8262 - val_loss: -9.2334e-01 - val_dice_coef: 0.9233 - val_dice_coef_loss: -9.2334e-01 - val_jaccard_coef: 0.8584
# Epoch 9/100
#  - 24s - loss: -9.0818e-01 - dice_coef: 0.9082 - dice_coef_loss: -9.0818e-01 - jaccard_coef: 0.8378 - val_loss: -9.2129e-01 - val_dice_coef: 0.9213 - val_dice_coef_loss: -9.2129e-01 - val_jaccard_coef: 0.8565
# Epoch 10/100
#  - 24s - loss: -9.1653e-01 - dice_coef: 0.9165 - dice_coef_loss: -9.1653e-01 - jaccard_coef: 0.8520 - val_loss: -9.2618e-01 - val_dice_coef: 0.9262 - val_dice_coef_loss: -9.2618e-01 - val_jaccard_coef: 0.8623
# Epoch 11/100
#  - 24s - loss: -9.1685e-01 - dice_coef: 0.9169 - dice_coef_loss: -9.1685e-01 - jaccard_coef: 0.8536 - val_loss: -9.2613e-01 - val_dice_coef: 0.9261 - val_dice_coef_loss: -9.2613e-01 - val_jaccard_coef: 0.8632
# Epoch 12/100
#  - 24s - loss: -9.1528e-01 - dice_coef: 0.9153 - dice_coef_loss: -9.1528e-01 - jaccard_coef: 0.8501 - val_loss: -9.2258e-01 - val_dice_coef: 0.9226 - val_dice_coef_loss: -9.2258e-01 - val_jaccard_coef: 0.8580
# Epoch 13/100
#  - 24s - loss: -9.2172e-01 - dice_coef: 0.9217 - dice_coef_loss: -9.2172e-01 - jaccard_coef: 0.8601 - val_loss: -9.2569e-01 - val_dice_coef: 0.9257 - val_dice_coef_loss: -9.2569e-01 - val_jaccard_coef: 0.8624
# Epoch 14/100
#  - 24s - loss: -9.2274e-01 - dice_coef: 0.9227 - dice_coef_loss: -9.2274e-01 - jaccard_coef: 0.8619 - val_loss: -9.3542e-01 - val_dice_coef: 0.9354 - val_dice_coef_loss: -9.3542e-01 - val_jaccard_coef: 0.8783
# Epoch 15/100
#  - 24s - loss: -9.2688e-01 - dice_coef: 0.9269 - dice_coef_loss: -9.2688e-01 - jaccard_coef: 0.8695 - val_loss: -9.3435e-01 - val_dice_coef: 0.9343 - val_dice_coef_loss: -9.3435e-01 - val_jaccard_coef: 0.8780
# Epoch 16/100
#  - 24s - loss: -9.2586e-01 - dice_coef: 0.9259 - dice_coef_loss: -9.2586e-01 - jaccard_coef: 0.8680 - val_loss: -9.3621e-01 - val_dice_coef: 0.9362 - val_dice_coef_loss: -9.3621e-01 - val_jaccard_coef: 0.8811
# Epoch 17/100
#  - 24s - loss: -9.3057e-01 - dice_coef: 0.9306 - dice_coef_loss: -9.3057e-01 - jaccard_coef: 0.8744 - val_loss: -9.3077e-01 - val_dice_coef: 0.9308 - val_dice_coef_loss: -9.3077e-01 - val_jaccard_coef: 0.8712
# Epoch 18/100
#  - 24s - loss: -9.3030e-01 - dice_coef: 0.9303 - dice_coef_loss: -9.3030e-01 - jaccard_coef: 0.8750 - val_loss: -9.2270e-01 - val_dice_coef: 0.9227 - val_dice_coef_loss: -9.2270e-01 - val_jaccard_coef: 0.8552
# Epoch 19/100
#  - 24s - loss: -9.2580e-01 - dice_coef: 0.9258 - dice_coef_loss: -9.2580e-01 - jaccard_coef: 0.8671 - val_loss: -9.3175e-01 - val_dice_coef: 0.9318 - val_dice_coef_loss: -9.3175e-01 - val_jaccard_coef: 0.8716
# Epoch 20/100
#  - 24s - loss: -9.3252e-01 - dice_coef: 0.9325 - dice_coef_loss: -9.3252e-01 - jaccard_coef: 0.8781 - val_loss: -9.3808e-01 - val_dice_coef: 0.9381 - val_dice_coef_loss: -9.3808e-01 - val_jaccard_coef: 0.8836
# Epoch 21/100
#  - 24s - loss: -9.2929e-01 - dice_coef: 0.9293 - dice_coef_loss: -9.2929e-01 - jaccard_coef: 0.8730 - val_loss: -9.1433e-01 - val_dice_coef: 0.9143 - val_dice_coef_loss: -9.1433e-01 - val_jaccard_coef: 0.8443
# Epoch 22/100
#  - 24s - loss: -9.3130e-01 - dice_coef: 0.9313 - dice_coef_loss: -9.3130e-01 - jaccard_coef: 0.8782 - val_loss: -8.0575e-01 - val_dice_coef: 0.8057 - val_dice_coef_loss: -8.0575e-01 - val_jaccard_coef: 0.6710
# Epoch 23/100
#  - 24s - loss: -9.2750e-01 - dice_coef: 0.9275 - dice_coef_loss: -9.2750e-01 - jaccard_coef: 0.8712 - val_loss: -9.4109e-01 - val_dice_coef: 0.9411 - val_dice_coef_loss: -9.4109e-01 - val_jaccard_coef: 0.8889
# Epoch 24/100
#  - 24s - loss: -9.3287e-01 - dice_coef: 0.9329 - dice_coef_loss: -9.3287e-01 - jaccard_coef: 0.8784 - val_loss: -9.3070e-01 - val_dice_coef: 0.9307 - val_dice_coef_loss: -9.3070e-01 - val_jaccard_coef: 0.8707
# Epoch 25/100
#  - 24s - loss: -9.3243e-01 - dice_coef: 0.9324 - dice_coef_loss: -9.3243e-01 - jaccard_coef: 0.8784 - val_loss: -9.4216e-01 - val_dice_coef: 0.9422 - val_dice_coef_loss: -9.4216e-01 - val_jaccard_coef: 0.8907
# Epoch 26/100
#  - 24s - loss: -9.3735e-01 - dice_coef: 0.9374 - dice_coef_loss: -9.3735e-01 - jaccard_coef: 0.8862 - val_loss: -9.4277e-01 - val_dice_coef: 0.9428 - val_dice_coef_loss: -9.4277e-01 - val_jaccard_coef: 0.8913
# Epoch 27/100
#  - 24s - loss: -9.3750e-01 - dice_coef: 0.9375 - dice_coef_loss: -9.3750e-01 - jaccard_coef: 0.8870 - val_loss: -9.4211e-01 - val_dice_coef: 0.9421 - val_dice_coef_loss: -9.4211e-01 - val_jaccard_coef: 0.8906
# Epoch 28/100
#  - 24s - loss: -9.3573e-01 - dice_coef: 0.9357 - dice_coef_loss: -9.3573e-01 - jaccard_coef: 0.8845 - val_loss: -9.4009e-01 - val_dice_coef: 0.9401 - val_dice_coef_loss: -9.4009e-01 - val_jaccard_coef: 0.8864
# Epoch 29/100
#  - 24s - loss: -9.3665e-01 - dice_coef: 0.9367 - dice_coef_loss: -9.3665e-01 - jaccard_coef: 0.8847 - val_loss: -9.4091e-01 - val_dice_coef: 0.9409 - val_dice_coef_loss: -9.4091e-01 - val_jaccard_coef: 0.8889
# Epoch 30/100
#  - 24s - loss: -9.3960e-01 - dice_coef: 0.9396 - dice_coef_loss: -9.3960e-01 - jaccard_coef: 0.8898 - val_loss: -9.4158e-01 - val_dice_coef: 0.9416 - val_dice_coef_loss: -9.4158e-01 - val_jaccard_coef: 0.8888
# Epoch 31/100
#  - 24s - loss: -9.4010e-01 - dice_coef: 0.9401 - dice_coef_loss: -9.4010e-01 - jaccard_coef: 0.8906 - val_loss: -9.3889e-01 - val_dice_coef: 0.9389 - val_dice_coef_loss: -9.3889e-01 - val_jaccard_coef: 0.8845
# Epoch 32/100
#  - 24s - loss: -9.3854e-01 - dice_coef: 0.9385 - dice_coef_loss: -9.3854e-01 - jaccard_coef: 0.8879 - val_loss: -9.3321e-01 - val_dice_coef: 0.9332 - val_dice_coef_loss: -9.3321e-01 - val_jaccard_coef: 0.8756
# Epoch 33/100
#  - 24s - loss: -9.3666e-01 - dice_coef: 0.9367 - dice_coef_loss: -9.3666e-01 - jaccard_coef: 0.8855 - val_loss: -9.3063e-01 - val_dice_coef: 0.9306 - val_dice_coef_loss: -9.3063e-01 - val_jaccard_coef: 0.8684
# Epoch 34/100
#  - 24s - loss: -9.3921e-01 - dice_coef: 0.9392 - dice_coef_loss: -9.3921e-01 - jaccard_coef: 0.8894 - val_loss: -9.3946e-01 - val_dice_coef: 0.9395 - val_dice_coef_loss: -9.3946e-01 - val_jaccard_coef: 0.8855
# Epoch 35/100
#  - 24s - loss: -9.3690e-01 - dice_coef: 0.9369 - dice_coef_loss: -9.3690e-01 - jaccard_coef: 0.8858 - val_loss: -9.4589e-01 - val_dice_coef: 0.9459 - val_dice_coef_loss: -9.4589e-01 - val_jaccard_coef: 0.8972
# Epoch 36/100
#  - 24s - loss: -9.3979e-01 - dice_coef: 0.9398 - dice_coef_loss: -9.3979e-01 - jaccard_coef: 0.8903 - val_loss: -9.2972e-01 - val_dice_coef: 0.9297 - val_dice_coef_loss: -9.2972e-01 - val_jaccard_coef: 0.8693
# Epoch 37/100
#  - 24s - loss: -9.3954e-01 - dice_coef: 0.9395 - dice_coef_loss: -9.3954e-01 - jaccard_coef: 0.8899 - val_loss: -9.4533e-01 - val_dice_coef: 0.9453 - val_dice_coef_loss: -9.4533e-01 - val_jaccard_coef: 0.8958
# Epoch 38/100
#  - 24s - loss: -9.3945e-01 - dice_coef: 0.9394 - dice_coef_loss: -9.3945e-01 - jaccard_coef: 0.8900 - val_loss: -9.3720e-01 - val_dice_coef: 0.9372 - val_dice_coef_loss: -9.3720e-01 - val_jaccard_coef: 0.8813
# Epoch 39/100
#  - 24s - loss: -9.4026e-01 - dice_coef: 0.9403 - dice_coef_loss: -9.4026e-01 - jaccard_coef: 0.8911 - val_loss: -9.4115e-01 - val_dice_coef: 0.9412 - val_dice_coef_loss: -9.4115e-01 - val_jaccard_coef: 0.8886
# Epoch 40/100
#  - 24s - loss: -9.4308e-01 - dice_coef: 0.9431 - dice_coef_loss: -9.4308e-01 - jaccard_coef: 0.8957 - val_loss: -9.4557e-01 - val_dice_coef: 0.9456 - val_dice_coef_loss: -9.4557e-01 - val_jaccard_coef: 0.8966
# Epoch 41/100
#  - 24s - loss: -9.4405e-01 - dice_coef: 0.9441 - dice_coef_loss: -9.4405e-01 - jaccard_coef: 0.8984 - val_loss: -9.4725e-01 - val_dice_coef: 0.9472 - val_dice_coef_loss: -9.4725e-01 - val_jaccard_coef: 0.8993
# Epoch 42/100
#  - 24s - loss: -9.4468e-01 - dice_coef: 0.9447 - dice_coef_loss: -9.4468e-01 - jaccard_coef: 0.8986 - val_loss: -9.4522e-01 - val_dice_coef: 0.9452 - val_dice_coef_loss: -9.4522e-01 - val_jaccard_coef: 0.8966
# Epoch 43/100
#  - 24s - loss: -9.4105e-01 - dice_coef: 0.9411 - dice_coef_loss: -9.4105e-01 - jaccard_coef: 0.8931 - val_loss: -9.4207e-01 - val_dice_coef: 0.9421 - val_dice_coef_loss: -9.4207e-01 - val_jaccard_coef: 0.8900
# Epoch 44/100
#  - 24s - loss: -9.4328e-01 - dice_coef: 0.9433 - dice_coef_loss: -9.4328e-01 - jaccard_coef: 0.8967 - val_loss: -9.4811e-01 - val_dice_coef: 0.9481 - val_dice_coef_loss: -9.4811e-01 - val_jaccard_coef: 0.9008
# Epoch 45/100
#  - 24s - loss: -9.3761e-01 - dice_coef: 0.9376 - dice_coef_loss: -9.3761e-01 - jaccard_coef: 0.8882 - val_loss: -9.3583e-01 - val_dice_coef: 0.9358 - val_dice_coef_loss: -9.3583e-01 - val_jaccard_coef: 0.8793
# Epoch 46/100
#  - 24s - loss: -9.4182e-01 - dice_coef: 0.9418 - dice_coef_loss: -9.4182e-01 - jaccard_coef: 0.8943 - val_loss: -9.4605e-01 - val_dice_coef: 0.9461 - val_dice_coef_loss: -9.4605e-01 - val_jaccard_coef: 0.8978
# Epoch 47/100
#  - 24s - loss: -9.4452e-01 - dice_coef: 0.9445 - dice_coef_loss: -9.4452e-01 - jaccard_coef: 0.8990 - val_loss: -9.4607e-01 - val_dice_coef: 0.9461 - val_dice_coef_loss: -9.4607e-01 - val_jaccard_coef: 0.8973
# Epoch 48/100
#  - 24s - loss: -9.4519e-01 - dice_coef: 0.9452 - dice_coef_loss: -9.4519e-01 - jaccard_coef: 0.9004 - val_loss: -9.4686e-01 - val_dice_coef: 0.9469 - val_dice_coef_loss: -9.4686e-01 - val_jaccard_coef: 0.8989
# Epoch 49/100
#  - 24s - loss: -9.4670e-01 - dice_coef: 0.9467 - dice_coef_loss: -9.4670e-01 - jaccard_coef: 0.9027 - val_loss: -9.4746e-01 - val_dice_coef: 0.9475 - val_dice_coef_loss: -9.4746e-01 - val_jaccard_coef: 0.9005
# Epoch 50/100
#  - 24s - loss: -9.4577e-01 - dice_coef: 0.9458 - dice_coef_loss: -9.4577e-01 - jaccard_coef: 0.9006 - val_loss: -9.4836e-01 - val_dice_coef: 0.9484 - val_dice_coef_loss: -9.4836e-01 - val_jaccard_coef: 0.9010
# Epoch 51/100
#  - 24s - loss: -9.4594e-01 - dice_coef: 0.9459 - dice_coef_loss: -9.4594e-01 - jaccard_coef: 0.9013 - val_loss: -9.3104e-01 - val_dice_coef: 0.9310 - val_dice_coef_loss: -9.3104e-01 - val_jaccard_coef: 0.8718
# Epoch 52/100
#  - 24s - loss: -9.4595e-01 - dice_coef: 0.9460 - dice_coef_loss: -9.4595e-01 - jaccard_coef: 0.9013 - val_loss: -9.5044e-01 - val_dice_coef: 0.9504 - val_dice_coef_loss: -9.5044e-01 - val_jaccard_coef: 0.9051
# Epoch 53/100
#  - 24s - loss: -9.4675e-01 - dice_coef: 0.9468 - dice_coef_loss: -9.4675e-01 - jaccard_coef: 0.9026 - val_loss: -9.5022e-01 - val_dice_coef: 0.9502 - val_dice_coef_loss: -9.5022e-01 - val_jaccard_coef: 0.9046
# Epoch 54/100
#  - 24s - loss: -9.4669e-01 - dice_coef: 0.9467 - dice_coef_loss: -9.4669e-01 - jaccard_coef: 0.9027 - val_loss: -9.4895e-01 - val_dice_coef: 0.9490 - val_dice_coef_loss: -9.4895e-01 - val_jaccard_coef: 0.9023
# Epoch 55/100
#  - 24s - loss: -9.4726e-01 - dice_coef: 0.9473 - dice_coef_loss: -9.4726e-01 - jaccard_coef: 0.9038 - val_loss: -9.4146e-01 - val_dice_coef: 0.9415 - val_dice_coef_loss: -9.4146e-01 - val_jaccard_coef: 0.8881
# Epoch 56/100
#  - 24s - loss: -9.4662e-01 - dice_coef: 0.9466 - dice_coef_loss: -9.4662e-01 - jaccard_coef: 0.9030 - val_loss: -9.4226e-01 - val_dice_coef: 0.9423 - val_dice_coef_loss: -9.4226e-01 - val_jaccard_coef: 0.8913
# Epoch 57/100
#  - 24s - loss: -9.4763e-01 - dice_coef: 0.9476 - dice_coef_loss: -9.4763e-01 - jaccard_coef: 0.9050 - val_loss: -9.4421e-01 - val_dice_coef: 0.9442 - val_dice_coef_loss: -9.4421e-01 - val_jaccard_coef: 0.8945
# Epoch 58/100
#  - 24s - loss: -9.4890e-01 - dice_coef: 0.9489 - dice_coef_loss: -9.4890e-01 - jaccard_coef: 0.9062 - val_loss: -9.4799e-01 - val_dice_coef: 0.9480 - val_dice_coef_loss: -9.4799e-01 - val_jaccard_coef: 0.9005
# Epoch 59/100
#  - 24s - loss: -9.4609e-01 - dice_coef: 0.9461 - dice_coef_loss: -9.4609e-01 - jaccard_coef: 0.9021 - val_loss: -9.4449e-01 - val_dice_coef: 0.9445 - val_dice_coef_loss: -9.4449e-01 - val_jaccard_coef: 0.8944
# Epoch 60/100
#  - 24s - loss: -9.4710e-01 - dice_coef: 0.9471 - dice_coef_loss: -9.4710e-01 - jaccard_coef: 0.9025 - val_loss: -9.4760e-01 - val_dice_coef: 0.9476 - val_dice_coef_loss: -9.4760e-01 - val_jaccard_coef: 0.9006
# Epoch 61/100
#  - 24s - loss: -9.4844e-01 - dice_coef: 0.9484 - dice_coef_loss: -9.4844e-01 - jaccard_coef: 0.9056 - val_loss: -9.4839e-01 - val_dice_coef: 0.9484 - val_dice_coef_loss: -9.4839e-01 - val_jaccard_coef: 0.9011
# Epoch 62/100
#  - 24s - loss: -9.4729e-01 - dice_coef: 0.9473 - dice_coef_loss: -9.4729e-01 - jaccard_coef: 0.9035 - val_loss: -9.4423e-01 - val_dice_coef: 0.9442 - val_dice_coef_loss: -9.4423e-01 - val_jaccard_coef: 0.8938
# Epoch 63/100
#  - 24s - loss: -9.4955e-01 - dice_coef: 0.9495 - dice_coef_loss: -9.4955e-01 - jaccard_coef: 0.9074 - val_loss: -9.4897e-01 - val_dice_coef: 0.9490 - val_dice_coef_loss: -9.4897e-01 - val_jaccard_coef: 0.9027
# Epoch 64/100
#  - 24s - loss: -9.4840e-01 - dice_coef: 0.9484 - dice_coef_loss: -9.4840e-01 - jaccard_coef: 0.9054 - val_loss: -9.4754e-01 - val_dice_coef: 0.9475 - val_dice_coef_loss: -9.4754e-01 - val_jaccard_coef: 0.8996
# Epoch 65/100
#  - 24s - loss: -9.4717e-01 - dice_coef: 0.9472 - dice_coef_loss: -9.4717e-01 - jaccard_coef: 0.9034 - val_loss: -9.4648e-01 - val_dice_coef: 0.9465 - val_dice_coef_loss: -9.4648e-01 - val_jaccard_coef: 0.8976
# Epoch 66/100
#  - 24s - loss: -9.4978e-01 - dice_coef: 0.9498 - dice_coef_loss: -9.4978e-01 - jaccard_coef: 0.9080 - val_loss: -9.5082e-01 - val_dice_coef: 0.9508 - val_dice_coef_loss: -9.5082e-01 - val_jaccard_coef: 0.9057
# Epoch 67/100
#  - 24s - loss: -9.4896e-01 - dice_coef: 0.9490 - dice_coef_loss: -9.4896e-01 - jaccard_coef: 0.9071 - val_loss: -9.4366e-01 - val_dice_coef: 0.9437 - val_dice_coef_loss: -9.4366e-01 - val_jaccard_coef: 0.8931
# Epoch 68/100
#  - 24s - loss: -9.5029e-01 - dice_coef: 0.9503 - dice_coef_loss: -9.5029e-01 - jaccard_coef: 0.9091 - val_loss: -9.5004e-01 - val_dice_coef: 0.9500 - val_dice_coef_loss: -9.5004e-01 - val_jaccard_coef: 0.9041
# Epoch 69/100
#  - 24s - loss: -9.5037e-01 - dice_coef: 0.9504 - dice_coef_loss: -9.5037e-01 - jaccard_coef: 0.9089 - val_loss: -9.4838e-01 - val_dice_coef: 0.9484 - val_dice_coef_loss: -9.4838e-01 - val_jaccard_coef: 0.9012
# Epoch 70/100
#  - 24s - loss: -9.4969e-01 - dice_coef: 0.9497 - dice_coef_loss: -9.4969e-01 - jaccard_coef: 0.9076 - val_loss: -9.5019e-01 - val_dice_coef: 0.9502 - val_dice_coef_loss: -9.5019e-01 - val_jaccard_coef: 0.9047
# Epoch 71/100
#  - 24s - loss: -9.5031e-01 - dice_coef: 0.9503 - dice_coef_loss: -9.5031e-01 - jaccard_coef: 0.9087 - val_loss: -9.4531e-01 - val_dice_coef: 0.9453 - val_dice_coef_loss: -9.4531e-01 - val_jaccard_coef: 0.8964
# Epoch 72/100
#  - 24s - loss: -9.4982e-01 - dice_coef: 0.9498 - dice_coef_loss: -9.4982e-01 - jaccard_coef: 0.9083 - val_loss: -9.4733e-01 - val_dice_coef: 0.9473 - val_dice_coef_loss: -9.4733e-01 - val_jaccard_coef: 0.8993
# Epoch 73/100
#  - 24s - loss: -9.5036e-01 - dice_coef: 0.9504 - dice_coef_loss: -9.5036e-01 - jaccard_coef: 0.9089 - val_loss: -9.4957e-01 - val_dice_coef: 0.9496 - val_dice_coef_loss: -9.4957e-01 - val_jaccard_coef: 0.9035
# Epoch 74/100
#  - 24s - loss: -9.5119e-01 - dice_coef: 0.9512 - dice_coef_loss: -9.5119e-01 - jaccard_coef: 0.9104 - val_loss: -9.5157e-01 - val_dice_coef: 0.9516 - val_dice_coef_loss: -9.5157e-01 - val_jaccard_coef: 0.9070
# Epoch 75/100
#  - 24s - loss: -9.4902e-01 - dice_coef: 0.9490 - dice_coef_loss: -9.4902e-01 - jaccard_coef: 0.9068 - val_loss: -9.5156e-01 - val_dice_coef: 0.9516 - val_dice_coef_loss: -9.5156e-01 - val_jaccard_coef: 0.9070
# Epoch 76/100
#  - 24s - loss: -9.5023e-01 - dice_coef: 0.9502 - dice_coef_loss: -9.5023e-01 - jaccard_coef: 0.9089 - val_loss: -9.4871e-01 - val_dice_coef: 0.9487 - val_dice_coef_loss: -9.4871e-01 - val_jaccard_coef: 0.9027
# Epoch 77/100
#  - 24s - loss: -9.5095e-01 - dice_coef: 0.9509 - dice_coef_loss: -9.5095e-01 - jaccard_coef: 0.9102 - val_loss: -9.4773e-01 - val_dice_coef: 0.9477 - val_dice_coef_loss: -9.4773e-01 - val_jaccard_coef: 0.9000
# Epoch 78/100
#  - 24s - loss: -9.5054e-01 - dice_coef: 0.9505 - dice_coef_loss: -9.5054e-01 - jaccard_coef: 0.9098 - val_loss: -9.4957e-01 - val_dice_coef: 0.9496 - val_dice_coef_loss: -9.4957e-01 - val_jaccard_coef: 0.9040
# Epoch 79/100
#  - 24s - loss: -9.5188e-01 - dice_coef: 0.9519 - dice_coef_loss: -9.5188e-01 - jaccard_coef: 0.9121 - val_loss: -9.5060e-01 - val_dice_coef: 0.9506 - val_dice_coef_loss: -9.5060e-01 - val_jaccard_coef: 0.9054
# Epoch 80/100
#  - 24s - loss: -9.5177e-01 - dice_coef: 0.9518 - dice_coef_loss: -9.5177e-01 - jaccard_coef: 0.9117 - val_loss: -9.5045e-01 - val_dice_coef: 0.9504 - val_dice_coef_loss: -9.5045e-01 - val_jaccard_coef: 0.9050
# Epoch 81/100
#  - 24s - loss: -9.5254e-01 - dice_coef: 0.9525 - dice_coef_loss: -9.5254e-01 - jaccard_coef: 0.9136 - val_loss: -9.4798e-01 - val_dice_coef: 0.9480 - val_dice_coef_loss: -9.4798e-01 - val_jaccard_coef: 0.9010
# Epoch 82/100
#  - 24s - loss: -9.5151e-01 - dice_coef: 0.9515 - dice_coef_loss: -9.5151e-01 - jaccard_coef: 0.9112 - val_loss: -9.4680e-01 - val_dice_coef: 0.9468 - val_dice_coef_loss: -9.4680e-01 - val_jaccard_coef: 0.8987
# Epoch 83/100
#  - 24s - loss: -9.5172e-01 - dice_coef: 0.9517 - dice_coef_loss: -9.5172e-01 - jaccard_coef: 0.9119 - val_loss: -9.4938e-01 - val_dice_coef: 0.9494 - val_dice_coef_loss: -9.4938e-01 - val_jaccard_coef: 0.9033
# Epoch 84/100
#  - 24s - loss: -9.5224e-01 - dice_coef: 0.9522 - dice_coef_loss: -9.5224e-01 - jaccard_coef: 0.9122 - val_loss: -9.4785e-01 - val_dice_coef: 0.9479 - val_dice_coef_loss: -9.4785e-01 - val_jaccard_coef: 0.9001
# Epoch 85/100
#  - 24s - loss: -9.5279e-01 - dice_coef: 0.9528 - dice_coef_loss: -9.5279e-01 - jaccard_coef: 0.9135 - val_loss: -9.5107e-01 - val_dice_coef: 0.9511 - val_dice_coef_loss: -9.5107e-01 - val_jaccard_coef: 0.9061
# Epoch 86/100
#  - 24s - loss: -9.5293e-01 - dice_coef: 0.9529 - dice_coef_loss: -9.5293e-01 - jaccard_coef: 0.9138 - val_loss: -9.5096e-01 - val_dice_coef: 0.9510 - val_dice_coef_loss: -9.5096e-01 - val_jaccard_coef: 0.9059
# Epoch 87/100
#  - 24s - loss: -9.5366e-01 - dice_coef: 0.9537 - dice_coef_loss: -9.5366e-01 - jaccard_coef: 0.9147 - val_loss: -9.4974e-01 - val_dice_coef: 0.9497 - val_dice_coef_loss: -9.4974e-01 - val_jaccard_coef: 0.9040
# Epoch 88/100
#  - 24s - loss: -9.5308e-01 - dice_coef: 0.9531 - dice_coef_loss: -9.5308e-01 - jaccard_coef: 0.9138 - val_loss: -9.5117e-01 - val_dice_coef: 0.9512 - val_dice_coef_loss: -9.5117e-01 - val_jaccard_coef: 0.9064
# Epoch 89/100
#  - 24s - loss: -9.5378e-01 - dice_coef: 0.9538 - dice_coef_loss: -9.5378e-01 - jaccard_coef: 0.9157 - val_loss: -9.5115e-01 - val_dice_coef: 0.9512 - val_dice_coef_loss: -9.5115e-01 - val_jaccard_coef: 0.9063
# Epoch 90/100
#  - 24s - loss: -9.5360e-01 - dice_coef: 0.9536 - dice_coef_loss: -9.5360e-01 - jaccard_coef: 0.9154 - val_loss: -9.5203e-01 - val_dice_coef: 0.9520 - val_dice_coef_loss: -9.5203e-01 - val_jaccard_coef: 0.9079
# Epoch 91/100
#  - 24s - loss: -9.5275e-01 - dice_coef: 0.9527 - dice_coef_loss: -9.5275e-01 - jaccard_coef: 0.9140 - val_loss: -9.5166e-01 - val_dice_coef: 0.9517 - val_dice_coef_loss: -9.5166e-01 - val_jaccard_coef: 0.9079
# Epoch 92/100
#  - 24s - loss: -9.5381e-01 - dice_coef: 0.9538 - dice_coef_loss: -9.5381e-01 - jaccard_coef: 0.9156 - val_loss: -9.5039e-01 - val_dice_coef: 0.9504 - val_dice_coef_loss: -9.5039e-01 - val_jaccard_coef: 0.9056
# Epoch 93/100
#  - 24s - loss: -9.5462e-01 - dice_coef: 0.9546 - dice_coef_loss: -9.5462e-01 - jaccard_coef: 0.9166 - val_loss: -9.4958e-01 - val_dice_coef: 0.9496 - val_dice_coef_loss: -9.4958e-01 - val_jaccard_coef: 0.9034
# Epoch 94/100
#  - 24s - loss: -9.5425e-01 - dice_coef: 0.9543 - dice_coef_loss: -9.5425e-01 - jaccard_coef: 0.9167 - val_loss: -9.5067e-01 - val_dice_coef: 0.9507 - val_dice_coef_loss: -9.5067e-01 - val_jaccard_coef: 0.9057
# Epoch 95/100
#  - 24s - loss: -9.5385e-01 - dice_coef: 0.9539 - dice_coef_loss: -9.5385e-01 - jaccard_coef: 0.9156 - val_loss: -9.5151e-01 - val_dice_coef: 0.9515 - val_dice_coef_loss: -9.5151e-01 - val_jaccard_coef: 0.9075
# Epoch 96/100
#  - 24s - loss: -9.5442e-01 - dice_coef: 0.9544 - dice_coef_loss: -9.5442e-01 - jaccard_coef: 0.9166 - val_loss: -9.4823e-01 - val_dice_coef: 0.9482 - val_dice_coef_loss: -9.4823e-01 - val_jaccard_coef: 0.9012
# Epoch 97/100
#  - 24s - loss: -9.5379e-01 - dice_coef: 0.9538 - dice_coef_loss: -9.5379e-01 - jaccard_coef: 0.9153 - val_loss: -9.4999e-01 - val_dice_coef: 0.9500 - val_dice_coef_loss: -9.4999e-01 - val_jaccard_coef: 0.9044
# Epoch 98/100
#  - 24s - loss: -9.5488e-01 - dice_coef: 0.9549 - dice_coef_loss: -9.5488e-01 - jaccard_coef: 0.9177 - val_loss: -9.5119e-01 - val_dice_coef: 0.9512 - val_dice_coef_loss: -9.5119e-01 - val_jaccard_coef: 0.9063
# Epoch 99/100
#  - 24s - loss: -9.5465e-01 - dice_coef: 0.9546 - dice_coef_loss: -9.5465e-01 - jaccard_coef: 0.9173 - val_loss: -9.5170e-01 - val_dice_coef: 0.9517 - val_dice_coef_loss: -9.5170e-01 - val_jaccard_coef: 0.9069
# Epoch 100/100
#  - 24s - loss: -9.5501e-01 - dice_coef: 0.9550 - dice_coef_loss: -9.5501e-01 - jaccard_coef: 0.9180 - val_loss: -9.4847e-01 - val_dice_coef: 0.9485 - val_dice_coef_loss: -9.4847e-01 - val_jaccard_coef: 0.9019

# %%
history.history
# Out:
# {'val_loss': [-0.691585320631663,
#   -0.8126357626914978,
#   -0.8471671565373738,
#   -0.8907128802935282,
#   -0.9016190854708354,
#   -0.8852467656135559,
#   -0.9033212685585021,
#   -0.923337721824646,
#   -0.9212943045298259,
#   -0.9261764732996622,
#   -0.9261338726679484,
#   -0.9225829799969991,
#   -0.9256927299499512,
#   -0.9354182410240174,
#   -0.9343472719192505,
#   -0.9362096476554871,
#   -0.9307687322298686,
#   -0.9227047332127889,
#   -0.9317535042762757,
#   -0.9380787897109986,
#   -0.9143335096041362,
#   -0.8057469383875528,
#   -0.9410854832331339,
#   -0.9306986292203268,
#   -0.94215980052948,
#   -0.9427691491444906,
#   -0.9421121104558309,
#   -0.9400920136769613,
#   -0.9409113176663717,
#   -0.9415819772084554,
#   -0.9388886531194051,
#   -0.9332118654251098,
#   -0.9306276631355286,
#   -0.9394560209910074,
#   -0.9458886988957723,
#   -0.9297154990832011,
#   -0.9453258466720581,
#   -0.9372011748949687,
#   -0.9411504284540813,
#   -0.9455733982721964,
#   -0.947246630191803,
#   -0.9452247373263041,
#   -0.9420653438568115,
#   -0.9481098635991414,
#   -0.9358326347668966,
#   -0.9460538093249004,
#   -0.9460718663533528,
#   -0.9468639151255289,
#   -0.9474637881914775,
#   -0.9483586430549622,
#   -0.9310442638397217,
#   -0.950441947778066,
#   -0.9502193633715311,
#   -0.9489503884315491,
#   -0.9414562018712361,
#   -0.9422583969434103,
#   -0.9442115092277527,
#   -0.9479917041460673,
#   -0.9444949213663737,
#   -0.9475979908307394,
#   -0.948391182422638,
#   -0.944232664903005,
#   -0.9489736413955688,
#   -0.9475355577468872,
#   -0.946477719148,
#   -0.9508156339327495,
#   -0.9436602290471395,
#   -0.9500433142979939,
#   -0.9483823005358378,
#   -0.9501885692278544,
#   -0.9453100927670797,
#   -0.9473250563939413,
#   -0.9495713639259339,
#   -0.9515736770629882,
#   -0.9515646584828694,
#   -0.9487097160021464,
#   -0.9477332894007365,
#   -0.9495651960372925,
#   -0.9506042663256328,
#   -0.9504484566052754,
#   -0.9479778718948364,
#   -0.9467994872728983,
#   -0.9493757502237956,
#   -0.9478518915176392,
#   -0.9510703945159912,
#   -0.9509552264213562,
#   -0.9497414946556091,
#   -0.9511651778221131,
#   -0.9511527347564698,
#   -0.952028603553772,
#   -0.9516624927520752,
#   -0.9503927365938822,
#   -0.9495843609174093,
#   -0.9506741666793823,
#   -0.9515073521931966,
#   -0.948232790629069,
#   -0.9499892767270406,
#   -0.9511914436022441,
#   -0.9517019708951314,
#   -0.948473444779714],
#  'val_dice_coef': [0.691585320631663,
#   0.8126357626914978,
#   0.8471671565373738,
#   0.8907128802935282,
#   0.9016190854708354,
#   0.8852467656135559,
#   0.9033212685585021,
#   0.923337721824646,
#   0.9212943045298259,
#   0.9261764732996622,
#   0.9261338726679484,
#   0.9225829799969991,
#   0.9256927299499512,
#   0.9354182410240174,
#   0.9343472719192505,
#   0.9362096476554871,
#   0.9307687322298686,
#   0.9227047332127889,
#   0.9317535042762757,
#   0.9380787897109986,
#   0.9143335096041362,
#   0.8057469383875528,
#   0.9410854832331339,
#   0.9306986292203268,
#   0.94215980052948,
#   0.9427691491444906,
#   0.9421121104558309,
#   0.9400920136769613,
#   0.9409113176663717,
#   0.9415819772084554,
#   0.9388886531194051,
#   0.9332118654251098,
#   0.9306276631355286,
#   0.9394560209910074,
#   0.9458886988957723,
#   0.9297154990832011,
#   0.9453258466720581,
#   0.9372011748949687,
#   0.9411504284540813,
#   0.9455733982721964,
#   0.947246630191803,
#   0.9452247373263041,
#   0.9420653438568115,
#   0.9481098635991414,
#   0.9358326347668966,
#   0.9460538093249004,
#   0.9460718663533528,
#   0.9468639151255289,
#   0.9474637881914775,
#   0.9483586430549622,
#   0.9310442638397217,
#   0.950441947778066,
#   0.9502193633715311,
#   0.9489503884315491,
#   0.9414562018712361,
#   0.9422583969434103,
#   0.9442115092277527,
#   0.9479917041460673,
#   0.9444949213663737,
#   0.9475979908307394,
#   0.948391182422638,
#   0.944232664903005,
#   0.9489736413955688,
#   0.9475355577468872,
#   0.946477719148,
#   0.9508156339327495,
#   0.9436602290471395,
#   0.9500433142979939,
#   0.9483823005358378,
#   0.9501885692278544,
#   0.9453100927670797,
#   0.9473250563939413,
#   0.9495713639259339,
#   0.9515736770629882,
#   0.9515646584828694,
#   0.9487097160021464,
#   0.9477332894007365,
#   0.9495651960372925,
#   0.9506042663256328,
#   0.9504484566052754,
#   0.9479778718948364,
#   0.9467994872728983,
#   0.9493757502237956,
#   0.9478518915176392,
#   0.9510703945159912,
#   0.9509552264213562,
#   0.9497414946556091,
#   0.9511651778221131,
#   0.9511527347564698,
#   0.952028603553772,
#   0.9516624927520752,
#   0.9503927365938822,
#   0.9495843609174093,
#   0.9506741666793823,
#   0.9515073521931966,
#   0.948232790629069,
#   0.9499892767270406,
#   0.9511914436022441,
#   0.9517019708951314,
#   0.948473444779714],
#  'val_dice_coef_loss': [-0.691585320631663,
#   -0.8126357626914978,
#   -0.8471671565373738,
#   -0.8907128802935282,
#   -0.9016190854708354,
#   -0.8852467656135559,
#   -0.9033212685585021,
#   -0.923337721824646,
#   -0.9212943045298259,
#   -0.9261764732996622,
#   -0.9261338726679484,
#   -0.9225829799969991,
#   -0.9256927299499512,
#   -0.9354182410240174,
#   -0.9343472719192505,
#   -0.9362096476554871,
#   -0.9307687322298686,
#   -0.9227047332127889,
#   -0.9317535042762757,
#   -0.9380787897109986,
#   -0.9143335096041362,
#   -0.8057469383875528,
#   -0.9410854832331339,
#   -0.9306986292203268,
#   -0.94215980052948,
#   -0.9427691491444906,
#   -0.9421121104558309,
#   -0.9400920136769613,
#   -0.9409113176663717,
#   -0.9415819772084554,
#   -0.9388886531194051,
#   -0.9332118654251098,
#   -0.9306276631355286,
#   -0.9394560209910074,
#   -0.9458886988957723,
#   -0.9297154990832011,
#   -0.9453258466720581,
#   -0.9372011748949687,
#   -0.9411504284540813,
#   -0.9455733982721964,
#   -0.947246630191803,
#   -0.9452247373263041,
#   -0.9420653438568115,
#   -0.9481098635991414,
#   -0.9358326347668966,
#   -0.9460538093249004,
#   -0.9460718663533528,
#   -0.9468639151255289,
#   -0.9474637881914775,
#   -0.9483586430549622,
#   -0.9310442638397217,
#   -0.950441947778066,
#   -0.9502193633715311,
#   -0.9489503884315491,
#   -0.9414562018712361,
#   -0.9422583969434103,
#   -0.9442115092277527,
#   -0.9479917041460673,
#   -0.9444949213663737,
#   -0.9475979908307394,
#   -0.948391182422638,
#   -0.944232664903005,
#   -0.9489736413955688,
#   -0.9475355577468872,
#   -0.946477719148,
#   -0.9508156339327495,
#   -0.9436602290471395,
#   -0.9500433142979939,
#   -0.9483823005358378,
#   -0.9501885692278544,
#   -0.9453100927670797,
#   -0.9473250563939413,
#   -0.9495713639259339,
#   -0.9515736770629882,
#   -0.9515646584828694,
#   -0.9487097160021464,
#   -0.9477332894007365,
#   -0.9495651960372925,
#   -0.9506042663256328,
#   -0.9504484566052754,
#   -0.9479778718948364,
#   -0.9467994872728983,
#   -0.9493757502237956,
#   -0.9478518915176392,
#   -0.9510703945159912,
#   -0.9509552264213562,
#   -0.9497414946556091,
#   -0.9511651778221131,
#   -0.9511527347564698,
#   -0.952028603553772,
#   -0.9516624927520752,
#   -0.9503927365938822,
#   -0.9495843609174093,
#   -0.9506741666793823,
#   -0.9515073521931966,
#   -0.948232790629069,
#   -0.9499892767270406,
#   -0.9511914436022441,
#   -0.9517019708951314,
#   -0.948473444779714],
#  'val_jaccard_coef': [0.5186183349291483,
#   0.6939742167790731,
#   0.7415343872706095,
#   0.8062834850947063,
#   0.8262853725751241,
#   0.7977752637863159,
#   0.8282077058156332,
#   0.8584271081288656,
#   0.8564845689137777,
#   0.8622760391235351,
#   0.8632258637746175,
#   0.8579993184407552,
#   0.8623690072695415,
#   0.8783320371309916,
#   0.8779929121335347,
#   0.8810880947113037,
#   0.8712080176671346,
#   0.8552496226628622,
#   0.8715816871325175,
#   0.8836025285720825,
#   0.8442592287063598,
#   0.671041419506073,
#   0.8889359911282857,
#   0.8707444969813029,
#   0.8906947795550029,
#   0.8913392464319865,
#   0.8906071392695109,
#   0.886395054658254,
#   0.8888599522908529,
#   0.8888193853696187,
#   0.8845176808039348,
#   0.8755944093068441,
#   0.8683814827601115,
#   0.8855318180720011,
#   0.8972495532035828,
#   0.8692825516064961,
#   0.8958419195810954,
#   0.881310601234436,
#   0.8886353826522827,
#   0.8966079020500183,
#   0.89932754834493,
#   0.8965858809153239,
#   0.8900328620274862,
#   0.9007606315612793,
#   0.8792656954129537,
#   0.8978310664494832,
#   0.8973274683952331,
#   0.8988845483462016,
#   0.9005118107795715,
#   0.9010097360610962,
#   0.8717609103520711,
#   0.9050877380371094,
#   0.9045960028966268,
#   0.9023142345746358,
#   0.8881483936309814,
#   0.8913028287887573,
#   0.8944747034708659,
#   0.9005173802375793,
#   0.8944434229532877,
#   0.90055362145106,
#   0.9011348056793212,
#   0.89379829565684,
#   0.9026602180798848,
#   0.8996257877349854,
#   0.8975668382644654,
#   0.9056506665547689,
#   0.8931194202105204,
#   0.9040771563847859,
#   0.9012495549519857,
#   0.9047193566958109,
#   0.89640252272288,
#   0.8992986838022868,
#   0.9034757200876872,
#   0.9069895609219869,
#   0.907048544883728,
#   0.9026622398694356,
#   0.9000157745679219,
#   0.9039846682548522,
#   0.9054475990931193,
#   0.9049563161532084,
#   0.9010188484191894,
#   0.8987365833918254,
#   0.9032589983940125,
#   0.9000581781069438,
#   0.9060660203297933,
#   0.9059071644147237,
#   0.9040196418762207,
#   0.9064451042811076,
#   0.9063224697113037,
#   0.9079258362452189,
#   0.9078976074854533,
#   0.9055869515736897,
#   0.9033584388097128,
#   0.9057208998998006,
#   0.9075389703114828,
#   0.9011995410919189,
#   0.9044051202138265,
#   0.9062714751561483,
#   0.9069444831212362,
#   0.9018801863988241],
#  'loss': [-0.5973543347480882,
#   -0.7977380969375372,
#   -0.8453053503483534,
#   -0.8668399827182293,
#   -0.8824406753480435,
#   -0.8851784101128578,
#   -0.8864566772431135,
#   -0.8999662379920482,
#   -0.9081790658831597,
#   -0.916529071778059,
#   -0.9168517193198205,
#   -0.9152844685316086,
#   -0.9217244294285775,
#   -0.9227398478984833,
#   -0.9268758854269982,
#   -0.9258614099025726,
#   -0.9305743178725243,
#   -0.9303036302328109,
#   -0.925797771960497,
#   -0.9325188033282756,
#   -0.9292907689511776,
#   -0.9312981915473938,
#   -0.9274989417195321,
#   -0.9328713166713715,
#   -0.9324348363280296,
#   -0.9373517854511738,
#   -0.9375030952692032,
#   -0.9357337233424187,
#   -0.9366528096795083,
#   -0.9396038174629211,
#   -0.9401032696664333,
#   -0.9385382561385631,
#   -0.9366604445874691,
#   -0.9392123346030712,
#   -0.9369026224315167,
#   -0.9397939397394657,
#   -0.9395430733263492,
#   -0.939446357935667,
#   -0.9402634851634503,
#   -0.9430759845674038,
#   -0.944053726196289,
#   -0.9446831350028515,
#   -0.9410535694658756,
#   -0.9432776127755642,
#   -0.937611247599125,
#   -0.9418210038542747,
#   -0.9445222324132919,
#   -0.9451916506886482,
#   -0.9467004965245723,
#   -0.9457704097032547,
#   -0.9459415233135223,
#   -0.9459500022232532,
#   -0.9467536260187626,
#   -0.9466887536644936,
#   -0.9472608555853367,
#   -0.9466236777603626,
#   -0.9476320618391036,
#   -0.9489042501151562,
#   -0.9460864692926407,
#   -0.9471007581055164,
#   -0.9484366439282894,
#   -0.9472917938232421,
#   -0.949549967944622,
#   -0.9484003382921219,
#   -0.9471718096733093,
#   -0.9497841402888298,
#   -0.9489628399908543,
#   -0.9502865643799305,
#   -0.9503669160604477,
#   -0.9496912780404091,
#   -0.9503128460049629,
#   -0.9498156939446926,
#   -0.9503602187335491,
#   -0.9511932843923568,
#   -0.9490193384885788,
#   -0.9502348390221595,
#   -0.9509499841928482,
#   -0.9505360196530819,
#   -0.9518845139443874,
#   -0.9517703233659267,
#   -0.9525431069731712,
#   -0.9515132716298104,
#   -0.9517237995564938,
#   -0.9522369410097599,
#   -0.952792226523161,
#   -0.9529296612739563,
#   -0.9536570097506046,
#   -0.9530809080600738,
#   -0.9537762708961963,
#   -0.9536001673340797,
#   -0.952745682746172,
#   -0.9538075618445874,
#   -0.954615188241005,
#   -0.9542523351311684,
#   -0.9538528509438038,
#   -0.9544167368113995,
#   -0.9537885212898254,
#   -0.9548819914460183,
#   -0.9546475528180599,
#   -0.9550128506124019],
#  'dice_coef': [0.5973543358656752,
#   0.7977380963414907,
#   0.8453053484857083,
#   0.8668399825692177,
#   0.8824406737089157,
#   0.885178409665823,
#   0.8864566732943058,
#   0.8999662382900715,
#   0.9081790664792061,
#   0.9165290740132331,
#   0.916851717531681,
#   0.9152844667434692,
#   0.9217244280874729,
#   0.9227398481965065,
#   0.9268758860230446,
#   0.9258614094555377,
#   0.9305743180215359,
#   0.9303036309778691,
#   0.9257977724075317,
#   0.9325188057124615,
#   0.9292907699942589,
#   0.9312981912493705,
#   0.9274989412724972,
#   0.9328713135421276,
#   0.9324348346889019,
#   0.9373517875373364,
#   0.937503093779087,
#   0.9357337227463722,
#   0.9366528084874153,
#   0.9396038191020488,
#   0.9401032714545727,
#   0.93853825584054,
#   0.9366604429483414,
#   0.9392123326659203,
#   0.936902623474598,
#   0.939793940782547,
#   0.9395430739223957,
#   0.9394463594257831,
#   0.9402634854614734,
#   0.943075984120369,
#   0.9440537275373936,
#   0.9446831379830837,
#   0.941053568571806,
#   0.9432776124775409,
#   0.937611247599125,
#   0.9418210047483444,
#   0.9445222349464893,
#   0.9451916508376599,
#   0.9467004957795143,
#   0.9457704113423824,
#   0.9459415243566036,
#   0.9459500023722649,
#   0.9467536281049251,
#   0.9466887512803077,
#   0.9472608572244644,
#   0.9466236762702465,
#   0.9476320642232895,
#   0.9489042520523071,
#   0.94608647108078,
#   0.9471007578074933,
#   0.9484366428852081,
#   0.947291791588068,
#   0.9495499706268311,
#   0.9484003363549709,
#   0.9471718086302281,
#   0.9497841380536556,
#   0.9489628407359123,
#   0.9502865619957447,
#   0.9503669169545174,
#   0.9496912772953511,
#   0.9503128433227539,
#   0.9498156943917274,
#   0.9503602185845375,
#   0.9511932869255543,
#   0.9490193364024162,
#   0.9502348385751247,
#   0.9509499825537204,
#   0.9505360199511051,
#   0.951884514093399,
#   0.9517703247070313,
#   0.9525431071221828,
#   0.9515132734179497,
#   0.9517238001525402,
#   0.9522369407117367,
#   0.9527922257781029,
#   0.9529296636581421,
#   0.9536570112407208,
#   0.9530809080600738,
#   0.953776272535324,
#   0.9536001671850681,
#   0.9527456821501255,
#   0.9538075633347034,
#   0.9546151888370514,
#   0.9542523340880871,
#   0.9538528496026992,
#   0.9544167350232601,
#   0.9537885223329067,
#   0.954881991147995,
#   0.9546475541591645,
#   0.9550128498673439],
#  'dice_coef_loss': [-0.5973543358656752,
#   -0.7977380963414907,
#   -0.8453053484857083,
#   -0.8668399825692177,
#   -0.8824406737089157,
#   -0.885178409665823,
#   -0.8864566732943058,
#   -0.8999662382900715,
#   -0.9081790664792061,
#   -0.9165290740132331,
#   -0.916851717531681,
#   -0.9152844667434692,
#   -0.9217244280874729,
#   -0.9227398481965065,
#   -0.9268758860230446,
#   -0.9258614094555377,
#   -0.9305743180215359,
#   -0.9303036309778691,
#   -0.9257977724075317,
#   -0.9325188057124615,
#   -0.9292907699942589,
#   -0.9312981912493705,
#   -0.9274989412724972,
#   -0.9328713135421276,
#   -0.9324348346889019,
#   -0.9373517875373364,
#   -0.937503093779087,
#   -0.9357337227463722,
#   -0.9366528084874153,
#   -0.9396038191020488,
#   -0.9401032714545727,
#   -0.93853825584054,
#   -0.9366604429483414,
#   -0.9392123326659203,
#   -0.936902623474598,
#   -0.939793940782547,
#   -0.9395430739223957,
#   -0.9394463594257831,
#   -0.9402634854614734,
#   -0.943075984120369,
#   -0.9440537275373936,
#   -0.9446831379830837,
#   -0.941053568571806,
#   -0.9432776124775409,
#   -0.937611247599125,
#   -0.9418210047483444,
#   -0.9445222349464893,
#   -0.9451916508376599,
#   -0.9467004957795143,
#   -0.9457704113423824,
#   -0.9459415243566036,
#   -0.9459500023722649,
#   -0.9467536281049251,
#   -0.9466887512803077,
#   -0.9472608572244644,
#   -0.9466236762702465,
#   -0.9476320642232895,
#   -0.9489042520523071,
#   -0.94608647108078,
#   -0.9471007578074933,
#   -0.9484366428852081,
#   -0.947291791588068,
#   -0.9495499706268311,
#   -0.9484003363549709,
#   -0.9471718086302281,
#   -0.9497841380536556,
#   -0.9489628407359123,
#   -0.9502865619957447,
#   -0.9503669169545174,
#   -0.9496912772953511,
#   -0.9503128433227539,
#   -0.9498156943917274,
#   -0.9503602185845375,
#   -0.9511932869255543,
#   -0.9490193364024162,
#   -0.9502348385751247,
#   -0.9509499825537204,
#   -0.9505360199511051,
#   -0.951884514093399,
#   -0.9517703247070313,
#   -0.9525431071221828,
#   -0.9515132734179497,
#   -0.9517238001525402,
#   -0.9522369407117367,
#   -0.9527922257781029,
#   -0.9529296636581421,
#   -0.9536570112407208,
#   -0.9530809080600738,
#   -0.953776272535324,
#   -0.9536001671850681,
#   -0.9527456821501255,
#   -0.9538075633347034,
#   -0.9546151888370514,
#   -0.9542523340880871,
#   -0.9538528496026992,
#   -0.9544167350232601,
#   -0.9537885223329067,
#   -0.954881991147995,
#   -0.9546475541591645,
#   -0.9550128498673439],
#  'jaccard_coef': [0.4638539293117356,
#   0.6770286159217358,
#   0.7439947065711021,
#   0.7755193176865578,
#   0.7991871778666974,
#   0.8030413807928563,
#   0.8055184656381607,
#   0.8261958886682987,
#   0.8378201062977314,
#   0.8520494079589844,
#   0.8535553014278412,
#   0.8500670817494392,
#   0.8600715450942517,
#   0.8619097998738289,
#   0.8695243027806282,
#   0.8679546420276165,
#   0.8744099140167236,
#   0.8749653992056846,
#   0.8670669583976269,
#   0.8781320734322071,
#   0.8729894453287125,
#   0.8782183480262756,
#   0.871179641187191,
#   0.8784320163726806,
#   0.8784121276438236,
#   0.8861800646781921,
#   0.8870213013887406,
#   0.8844620364904404,
#   0.8847274987399578,
#   0.8897903871536255,
#   0.8905621947348118,
#   0.887925635278225,
#   0.8855390039086342,
#   0.8893717168271542,
#   0.8857996641099453,
#   0.8902700878679752,
#   0.8898646521568299,
#   0.8900307413935661,
#   0.8911030471324921,
#   0.8956630429625512,
#   0.8983596254885197,
#   0.8986226853728294,
#   0.8930536650121212,
#   0.8966738034784794,
#   0.8882171370089054,
#   0.8942969423532486,
#   0.8990349064767361,
#   0.9003602936863899,
#   0.9027353847026824,
#   0.9006449717283249,
#   0.901342838704586,
#   0.9012681825459004,
#   0.9026339589059353,
#   0.9026914332807064,
#   0.9038057662546635,
#   0.9030041788518429,
#   0.905034047216177,
#   0.906191296428442,
#   0.902104236483574,
#   0.9025266064703464,
#   0.905590081512928,
#   0.9035151958465576,
#   0.9073793932795524,
#   0.9054240947961807,
#   0.903402132242918,
#   0.9080485361814499,
#   0.9070534783601761,
#   0.9091460120677948,
#   0.90894984126091,
#   0.9075903131067753,
#   0.9086755378544331,
#   0.9082936121523381,
#   0.9089199037849903,
#   0.9104099567234516,
#   0.9067857134342193,
#   0.9088715629279613,
#   0.9101522727310658,
#   0.9098358409106732,
#   0.9120564343035221,
#   0.9116929782927037,
#   0.9135822814702987,
#   0.9111596767604351,
#   0.9118985144793987,
#   0.9122362312674522,
#   0.9134699732065201,
#   0.9138353818655014,
#   0.914692095220089,
#   0.9138442367315293,
#   0.9157045024633408,
#   0.915405467748642,
#   0.9139579635858536,
#   0.9155777643620968,
#   0.9166351203620434,
#   0.9166854073107242,
#   0.9156376712024212,
#   0.916624273955822,
#   0.9152577070891857,
#   0.9176543332636357,
#   0.9172635047137737,
#   0.9180304619669915]}

# %%
plt.plot(history.history['jaccard_coef'])
plt.plot(history.history['dice_coef'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Jaccard Index', 'Dice Coefficient'], loc='upper left')
plt.show()

# %%
from keras.utils import plot_model  
plot_model(model, to_file='model-zf_224.png', show_shapes=True, show_layer_names=True)  
from IPython.display import FileLink
FileLink('model-zf_224.png')
# Out:
# /home/ubuntu/workspace/Fundus_UNET/model-zf_224.png

# %% [markdown]
# # Predictions

# %%
from tqdm import tqdm

# %%
df_test = pd.read_csv('data2/data/test.csv')
ids_test = df_test['img'].map(lambda s: s.split('.')[0])

# %%
names = []
for id in ids_test:
    names.append('{}.jpg'.format(id))

# %%
model.load_weights(filepath='weights/best_zf_unet_224.h5')

# %%
val_batch_size = 1

# %%
print('Predicting on {} samples with batch_size = {}...'.format(len(ids_test), val_batch_size))
for start in tqdm(range(0, len(ids_test), val_batch_size)):
    x_batch = []
    end = min(start + val_batch_size, len(ids_test))
    ids_test_batch = ids_test[start:end]
    for id in ids_test_batch.values:
        img = cv2.imread('data2/data/test/test/{}.jpg'.format(id))
        orig_width = np.shape(img)[1]
        orig_height = np.shape(img)[0]
        img = cv2.resize(img, (input_size, input_size))
        x_batch.append(img)
    x_batch = np.array(x_batch, np.float32) / 255
    preds = model.predict_on_batch(x_batch)
    for pred in preds:
        prob = cv2.resize(pred, (orig_width, orig_height))
        mask = prob > threshold
        mask = mask*255
        fig = plt.figure()
        ax = fig.add_subplot(1, 1, 1)
        ax.imshow(mask)
        plt.show()
        cv2.imwrite('data2/data/DL_masksZF_unet/{}.png'.format(id),mask)
# Out:
#   0%|          | 0/265 [00:00<?, ?it/s]
# Predicting on 265 samples with batch_size = 1...
#   0%|          | 1/265 [00:00<04:06,  1.07it/s]
#   1%|          | 2/265 [00:01<02:36,  1.68it/s]
#   1%|          | 3/265 [00:01<02:06,  2.07it/s]
#   2%|▏         | 4/265 [00:01<01:51,  2.33it/s]
#   2%|▏         | 5/265 [00:01<01:42,  2.53it/s]
#   2%|▏         | 6/265 [00:02<01:36,  2.68it/s]
#   3%|▎         | 7/265 [00:02<01:32,  2.79it/s]
#   3%|▎         | 8/265 [00:02<01:28,  2.89it/s]
#   3%|▎         | 9/265 [00:03<01:26,  2.97it/s]
#   4%|▍         | 10/265 [00:03<01:24,  3.02it/s]
#   4%|▍         | 11/265 [00:03<01:22,  3.08it/s]
#   5%|▍         | 12/265 [00:03<01:21,  3.12it/s]
#   5%|▍         | 13/265 [00:04<01:19,  3.16it/s]
#   5%|▌         | 14/265 [00:04<01:18,  3.20it/s]
#   6%|▌         | 15/265 [00:04<01:17,  3.23it/s]
#   6%|▌         | 16/265 [00:04<01:16,  3.26it/s]
#   6%|▋         | 17/265 [00:05<01:15,  3.29it/s]
#   7%|▋         | 18/265 [00:05<01:14,  3.32it/s]
#   7%|▋         | 19/265 [00:05<01:13,  3.34it/s]
#   8%|▊         | 20/265 [00:05<01:13,  3.35it/s]
#   8%|▊         | 21/265 [00:06<01:12,  3.37it/s]
#   8%|▊         | 22/265 [00:06<01:11,  3.39it/s]
#   9%|▊         | 23/265 [00:06<01:11,  3.41it/s]
#   9%|▉         | 24/265 [00:07<01:10,  3.42it/s]
#   9%|▉         | 25/265 [00:07<01:09,  3.43it/s]
#  10%|▉         | 26/265 [00:07<01:09,  3.44it/s]
#  10%|█         | 27/265 [00:07<01:08,  3.45it/s]
#  11%|█         | 28/265 [00:08<01:08,  3.46it/s]
#  11%|█         | 29/265 [00:08<01:07,  3.47it/s]
#  11%|█▏        | 30/265 [00:08<01:07,  3.48it/s]
#  12%|█▏        | 31/265 [00:08<01:07,  3.49it/s]
#  12%|█▏        | 32/265 [00:09<01:06,  3.50it/s]
#  12%|█▏        | 33/265 [00:09<01:06,  3.51it/s]
#  13%|█▎        | 34/265 [00:09<01:05,  3.51it/s]
#  13%|█▎        | 35/265 [00:09<01:05,  3.52it/s]
#  14%|█▎        | 36/265 [00:10<01:04,  3.53it/s]
#  14%|█▍        | 37/265 [00:10<01:04,  3.53it/s]
#  14%|█▍        | 38/265 [00:10<01:04,  3.54it/s]
#  15%|█▍        | 39/265 [00:11<01:03,  3.54it/s]
#  15%|█▌        | 40/265 [00:11<01:03,  3.55it/s]
#  15%|█▌        | 41/265 [00:11<01:02,  3.56it/s]
#  16%|█▌        | 42/265 [00:11<01:02,  3.56it/s]
#  16%|█▌        | 43/265 [00:12<01:02,  3.57it/s]
#  17%|█▋        | 44/265 [00:12<01:01,  3.57it/s]
#  17%|█▋        | 45/265 [00:12<01:01,  3.56it/s]
#  17%|█▋        | 46/265 [00:12<01:01,  3.56it/s]
#  18%|█▊        | 47/265 [00:13<01:01,  3.57it/s]
#  18%|█▊        | 48/265 [00:13<01:00,  3.57it/s]
#  18%|█▊        | 49/265 [00:13<01:00,  3.58it/s]
#  19%|█▉        | 50/265 [00:13<01:00,  3.58it/s]
#  19%|█▉        | 51/265 [00:14<00:59,  3.58it/s]
#  20%|█▉        | 52/265 [00:14<00:59,  3.59it/s]
#  20%|██        | 53/265 [00:14<00:59,  3.59it/s]
#  20%|██        | 54/265 [00:15<00:58,  3.59it/s]
#  21%|██        | 55/265 [00:15<00:58,  3.60it/s]
#  21%|██        | 56/265 [00:15<00:58,  3.60it/s]
#  22%|██▏       | 57/265 [00:15<00:57,  3.60it/s]
#  22%|██▏       | 58/265 [00:16<00:57,  3.60it/s]
#  22%|██▏       | 59/265 [00:16<00:57,  3.60it/s]
#  23%|██▎       | 60/265 [00:16<00:56,  3.60it/s]
#  23%|██▎       | 61/265 [00:16<00:56,  3.61it/s]
#  23%|██▎       | 62/265 [00:17<00:56,  3.61it/s]
#  24%|██▍       | 63/265 [00:17<00:56,  3.57it/s]
#  24%|██▍       | 64/265 [00:17<00:56,  3.58it/s]
#  25%|██▍       | 65/265 [00:18<00:55,  3.58it/s]
#  25%|██▍       | 66/265 [00:18<00:55,  3.58it/s]
#  25%|██▌       | 67/265 [00:18<00:55,  3.59it/s]
#  26%|██▌       | 68/265 [00:18<00:54,  3.59it/s]
#  26%|██▌       | 69/265 [00:19<00:54,  3.60it/s]
#  26%|██▋       | 70/265 [00:19<00:54,  3.60it/s]
#  27%|██▋       | 71/265 [00:19<00:53,  3.60it/s]
#  27%|██▋       | 72/265 [00:19<00:53,  3.61it/s]
#  28%|██▊       | 73/265 [00:20<00:53,  3.61it/s]
#  28%|██▊       | 74/265 [00:20<00:52,  3.61it/s]
#  28%|██▊       | 75/265 [00:20<00:52,  3.62it/s]
#  29%|██▊       | 76/265 [00:20<00:52,  3.62it/s]
#  29%|██▉       | 77/265 [00:21<00:51,  3.62it/s]
#  29%|██▉       | 78/265 [00:21<00:51,  3.61it/s]
#  30%|██▉       | 79/265 [00:21<00:51,  3.61it/s]
#  30%|███       | 80/265 [00:22<00:51,  3.60it/s]
#  31%|███       | 81/265 [00:22<00:51,  3.60it/s]
#  31%|███       | 82/265 [00:22<00:50,  3.61it/s]
#  31%|███▏      | 83/265 [00:23<00:50,  3.60it/s]
#  32%|███▏      | 84/265 [00:23<00:50,  3.60it/s]
#  32%|███▏      | 85/265 [00:23<00:50,  3.60it/s]
#  32%|███▏      | 86/265 [00:23<00:49,  3.60it/s]
#  33%|███▎      | 87/265 [00:24<00:49,  3.60it/s]
#  33%|███▎      | 88/265 [00:24<00:49,  3.61it/s]
#  34%|███▎      | 89/265 [00:24<00:48,  3.61it/s]
#  34%|███▍      | 90/265 [00:24<00:48,  3.61it/s]
#  34%|███▍      | 91/265 [00:25<00:48,  3.61it/s]
#  35%|███▍      | 92/265 [00:25<00:47,  3.61it/s]
#  35%|███▌      | 93/265 [00:25<00:47,  3.62it/s]
#  35%|███▌      | 94/265 [00:26<00:47,  3.61it/s]
#  36%|███▌      | 95/265 [00:26<00:47,  3.61it/s]
#  36%|███▌      | 96/265 [00:26<00:46,  3.61it/s]
#  37%|███▋      | 97/265 [00:26<00:46,  3.61it/s]
#  37%|███▋      | 98/265 [00:27<00:46,  3.62it/s]
#  37%|███▋      | 99/265 [00:27<00:45,  3.62it/s]
#  38%|███▊      | 100/265 [00:27<00:45,  3.62it/s]
#  38%|███▊      | 101/265 [00:27<00:45,  3.62it/s]
#  38%|███▊      | 102/265 [00:28<00:44,  3.63it/s]
#  39%|███▉      | 103/265 [00:28<00:44,  3.63it/s]
#  39%|███▉      | 104/265 [00:28<00:44,  3.63it/s]
#  40%|███▉      | 105/265 [00:28<00:44,  3.63it/s]
#  40%|████      | 106/265 [00:29<00:43,  3.64it/s]
#  40%|████      | 107/265 [00:29<00:43,  3.64it/s]
#  41%|████      | 108/265 [00:29<00:43,  3.64it/s]
#  41%|████      | 109/265 [00:29<00:42,  3.64it/s]
#  42%|████▏     | 110/265 [00:30<00:42,  3.65it/s]
#  42%|████▏     | 111/265 [00:30<00:42,  3.65it/s]
#  42%|████▏     | 112/265 [00:30<00:41,  3.65it/s]
#  43%|████▎     | 113/265 [00:30<00:41,  3.65it/s]
#  43%|████▎     | 114/265 [00:31<00:41,  3.65it/s]
#  43%|████▎     | 115/265 [00:31<00:41,  3.66it/s]
#  44%|████▍     | 116/265 [00:31<00:40,  3.66it/s]
#  44%|████▍     | 117/265 [00:31<00:40,  3.66it/s]
#  45%|████▍     | 118/265 [00:32<00:40,  3.66it/s]
#  45%|████▍     | 119/265 [00:32<00:39,  3.66it/s]
#  45%|████▌     | 120/265 [00:32<00:39,  3.67it/s]
#  46%|████▌     | 121/265 [00:32<00:39,  3.67it/s]
#  46%|████▌     | 122/265 [00:33<00:38,  3.67it/s]
#  46%|████▋     | 123/265 [00:33<00:38,  3.67it/s]
#  47%|████▋     | 124/265 [00:33<00:38,  3.67it/s]
#  47%|████▋     | 125/265 [00:34<00:38,  3.67it/s]
#  48%|████▊     | 126/265 [00:34<00:37,  3.67it/s]
#  48%|████▊     | 127/265 [00:34<00:37,  3.67it/s]
#  48%|████▊     | 128/265 [00:34<00:37,  3.68it/s]
#  49%|████▊     | 129/265 [00:35<00:36,  3.68it/s]
#  49%|████▉     | 130/265 [00:35<00:36,  3.68it/s]
#  49%|████▉     | 131/265 [00:35<00:36,  3.68it/s]
#  50%|████▉     | 132/265 [00:35<00:36,  3.68it/s]
#  50%|█████     | 133/265 [00:36<00:35,  3.68it/s]
#  51%|█████     | 134/265 [00:36<00:35,  3.68it/s]
#  51%|█████     | 135/265 [00:36<00:35,  3.68it/s]
#  51%|█████▏    | 136/265 [00:37<00:35,  3.65it/s]
#  52%|█████▏    | 137/265 [00:37<00:35,  3.65it/s]
#  52%|█████▏    | 138/265 [00:37<00:34,  3.66it/s]
#  52%|█████▏    | 139/265 [00:38<00:34,  3.66it/s]
#  53%|█████▎    | 140/265 [00:38<00:34,  3.66it/s]
#  53%|█████▎    | 141/265 [00:38<00:33,  3.66it/s]
#  54%|█████▎    | 142/265 [00:38<00:33,  3.66it/s]
#  54%|█████▍    | 143/265 [00:39<00:33,  3.66it/s]
#  54%|█████▍    | 144/265 [00:39<00:33,  3.66it/s]
#  55%|█████▍    | 145/265 [00:39<00:32,  3.66it/s]
#  55%|█████▌    | 146/265 [00:39<00:32,  3.66it/s]
#  55%|█████▌    | 147/265 [00:40<00:32,  3.66it/s]
#  56%|█████▌    | 148/265 [00:40<00:31,  3.66it/s]
#  56%|█████▌    | 149/265 [00:40<00:31,  3.67it/s]
#  57%|█████▋    | 150/265 [00:40<00:31,  3.67it/s]
#  57%|█████▋    | 151/265 [00:41<00:31,  3.66it/s]
#  57%|█████▋    | 152/265 [00:41<00:30,  3.67it/s]
#  58%|█████▊    | 153/265 [00:41<00:30,  3.67it/s]
#  58%|█████▊    | 154/265 [00:41<00:30,  3.67it/s]
#  58%|█████▊    | 155/265 [00:42<00:29,  3.67it/s]
#  59%|█████▉    | 156/265 [00:42<00:29,  3.67it/s]
#  59%|█████▉    | 157/265 [00:42<00:29,  3.67it/s]
#  60%|█████▉    | 158/265 [00:43<00:29,  3.67it/s]
#  60%|██████    | 159/265 [00:43<00:28,  3.67it/s]
#  60%|██████    | 160/265 [00:43<00:28,  3.68it/s]
#  61%|██████    | 161/265 [00:43<00:28,  3.68it/s]
#  61%|██████    | 162/265 [00:44<00:28,  3.68it/s]
#  62%|██████▏   | 163/265 [00:44<00:27,  3.68it/s]
#  62%|██████▏   | 164/265 [00:44<00:27,  3.68it/s]
#  62%|██████▏   | 165/265 [00:44<00:27,  3.68it/s]
#  63%|██████▎   | 166/265 [00:45<00:26,  3.68it/s]
#  63%|██████▎   | 167/265 [00:45<00:26,  3.68it/s]
#  63%|██████▎   | 168/265 [00:45<00:26,  3.69it/s]
#  64%|██████▍   | 169/265 [00:45<00:26,  3.69it/s]
#  64%|██████▍   | 170/265 [00:46<00:25,  3.69it/s]
#  65%|██████▍   | 171/265 [00:46<00:25,  3.69it/s]
#  65%|██████▍   | 172/265 [00:46<00:25,  3.69it/s]
#  65%|██████▌   | 173/265 [00:46<00:24,  3.69it/s]
#  66%|██████▌   | 174/265 [00:47<00:24,  3.69it/s]
#  66%|██████▌   | 175/265 [00:47<00:24,  3.69it/s]
#  66%|██████▋   | 176/265 [00:47<00:24,  3.69it/s]
#  67%|██████▋   | 177/265 [00:47<00:23,  3.70it/s]
#  67%|██████▋   | 178/265 [00:48<00:23,  3.70it/s]
#  68%|██████▊   | 179/265 [00:48<00:23,  3.70it/s]
#  68%|██████▊   | 180/265 [00:48<00:22,  3.70it/s]
#  68%|██████▊   | 181/265 [00:48<00:22,  3.70it/s]
#  69%|██████▊   | 182/265 [00:49<00:22,  3.70it/s]
#  69%|██████▉   | 183/265 [00:49<00:22,  3.70it/s]
#  69%|██████▉   | 184/265 [00:49<00:21,  3.70it/s]
#  70%|██████▉   | 185/265 [00:49<00:21,  3.70it/s]
#  70%|███████   | 186/265 [00:50<00:21,  3.71it/s]
#  71%|███████   | 187/265 [00:50<00:21,  3.71it/s]
#  71%|███████   | 188/265 [00:50<00:20,  3.71it/s]
#  71%|███████▏  | 189/265 [00:50<00:20,  3.71it/s]
#  72%|███████▏  | 190/265 [00:51<00:20,  3.71it/s]
#  72%|███████▏  | 191/265 [00:51<00:19,  3.71it/s]
#  72%|███████▏  | 192/265 [00:51<00:19,  3.71it/s]
#  73%|███████▎  | 193/265 [00:52<00:19,  3.71it/s]
#  73%|███████▎  | 194/265 [00:52<00:19,  3.71it/s]
#  74%|███████▎  | 195/265 [00:52<00:18,  3.71it/s]
#  74%|███████▍  | 196/265 [00:52<00:18,  3.71it/s]
#  74%|███████▍  | 197/265 [00:53<00:18,  3.71it/s]
#  75%|███████▍  | 198/265 [00:53<00:18,  3.71it/s]
#  75%|███████▌  | 199/265 [00:53<00:17,  3.71it/s]
#  75%|███████▌  | 200/265 [00:53<00:17,  3.72it/s]
#  76%|███████▌  | 201/265 [00:54<00:17,  3.72it/s]
#  76%|███████▌  | 202/265 [00:54<00:16,  3.72it/s]
#  77%|███████▋  | 203/265 [00:54<00:16,  3.72it/s]
#  77%|███████▋  | 204/265 [00:54<00:16,  3.72it/s]
#  77%|███████▋  | 205/265 [00:55<00:16,  3.72it/s]
#  78%|███████▊  | 206/265 [00:55<00:15,  3.72it/s]
#  78%|███████▊  | 207/265 [00:55<00:15,  3.72it/s]
#  78%|███████▊  | 208/265 [00:55<00:15,  3.72it/s]
#  79%|███████▉  | 209/265 [00:56<00:15,  3.71it/s]
#  79%|███████▉  | 210/265 [00:56<00:14,  3.71it/s]
#  80%|███████▉  | 211/265 [00:56<00:14,  3.71it/s]
#  80%|████████  | 212/265 [00:57<00:14,  3.71it/s]
#  80%|████████  | 213/265 [00:57<00:14,  3.71it/s]
#  81%|████████  | 214/265 [00:57<00:13,  3.71it/s]
#  81%|████████  | 215/265 [00:57<00:13,  3.71it/s]
#  82%|████████▏ | 216/265 [00:58<00:13,  3.71it/s]
#  82%|████████▏ | 217/265 [00:58<00:12,  3.71it/s]
#  82%|████████▏ | 218/265 [00:58<00:12,  3.71it/s]
#  83%|████████▎ | 219/265 [00:59<00:12,  3.71it/s]
#  83%|████████▎ | 220/265 [00:59<00:12,  3.71it/s]
#  83%|████████▎ | 221/265 [00:59<00:11,  3.71it/s]
#  84%|████████▍ | 222/265 [00:59<00:11,  3.71it/s]
#  84%|████████▍ | 223/265 [01:00<00:11,  3.71it/s]
#  85%|████████▍ | 224/265 [01:00<00:11,  3.71it/s]
#  85%|████████▍ | 225/265 [01:00<00:10,  3.72it/s]
#  85%|████████▌ | 226/265 [01:00<00:10,  3.72it/s]
#  86%|████████▌ | 227/265 [01:01<00:10,  3.72it/s]
#  86%|████████▌ | 228/265 [01:01<00:09,  3.72it/s]
#  86%|████████▋ | 229/265 [01:01<00:09,  3.72it/s]
#  87%|████████▋ | 230/265 [01:01<00:09,  3.72it/s]
#  87%|████████▋ | 231/265 [01:02<00:09,  3.72it/s]
#  88%|████████▊ | 232/265 [01:02<00:08,  3.72it/s]
#  88%|████████▊ | 233/265 [01:02<00:08,  3.72it/s]
#  88%|████████▊ | 234/265 [01:02<00:08,  3.72it/s]
#  89%|████████▊ | 235/265 [01:03<00:08,  3.72it/s]
#  89%|████████▉ | 236/265 [01:03<00:07,  3.72it/s]
#  89%|████████▉ | 237/265 [01:03<00:07,  3.72it/s]
#  90%|████████▉ | 238/265 [01:03<00:07,  3.72it/s]
#  90%|█████████ | 239/265 [01:04<00:06,  3.72it/s]
#  91%|█████████ | 240/265 [01:04<00:06,  3.72it/s]
#  91%|█████████ | 241/265 [01:04<00:06,  3.72it/s]
#  91%|█████████▏| 242/265 [01:04<00:06,  3.73it/s]
#  92%|█████████▏| 243/265 [01:05<00:05,  3.73it/s]
#  92%|█████████▏| 244/265 [01:05<00:05,  3.73it/s]
#  92%|█████████▏| 245/265 [01:05<00:05,  3.73it/s]
#  93%|█████████▎| 246/265 [01:05<00:05,  3.73it/s]
#  93%|█████████▎| 247/265 [01:06<00:04,  3.73it/s]
#  94%|█████████▎| 248/265 [01:06<00:04,  3.73it/s]
#  94%|█████████▍| 249/265 [01:06<00:04,  3.73it/s]
#  94%|█████████▍| 250/265 [01:07<00:04,  3.73it/s]
#  95%|█████████▍| 251/265 [01:07<00:03,  3.73it/s]
#  95%|█████████▌| 252/265 [01:07<00:03,  3.73it/s]
#  95%|█████████▌| 253/265 [01:07<00:03,  3.73it/s]
#  96%|█████████▌| 254/265 [01:08<00:02,  3.73it/s]
#  96%|█████████▌| 255/265 [01:08<00:02,  3.73it/s]
#  97%|█████████▋| 256/265 [01:08<00:02,  3.73it/s]
#  97%|█████████▋| 257/265 [01:08<00:02,  3.73it/s]
#  97%|█████████▋| 258/265 [01:09<00:01,  3.73it/s]
#  98%|█████████▊| 259/265 [01:09<00:01,  3.73it/s]
#  98%|█████████▊| 260/265 [01:09<00:01,  3.73it/s]
#  98%|█████████▊| 261/265 [01:10<00:01,  3.73it/s]
#  99%|█████████▉| 262/265 [01:10<00:00,  3.73it/s]
#  99%|█████████▉| 263/265 [01:10<00:00,  3.73it/s]
# 100%|█████████▉| 264/265 [01:10<00:00,  3.73it/s]
# 100%|██████████| 265/265 [01:11<00:00,  3.73it/s]
