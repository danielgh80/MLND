# %% [markdown]
# # Load libraries

# %%
import cv2
import numpy as np
import pandas as pd

from keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint, TensorBoard
from keras.models import Model
from keras.layers import Input, concatenate, Conv2D, MaxPooling2D, Activation, UpSampling2D, BatchNormalization
from keras.optimizers import RMSprop
from keras.losses import binary_crossentropy
import keras.backend as K

from sklearn.model_selection import train_test_split

import matplotlib.pyplot as plt
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py:1067: UserWarning: Duplicate key in file "/home/ubuntu/.config/matplotlib/matplotlibrc", line #2
#   (fname, cnt))
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py:1067: UserWarning: Duplicate key in file "/home/ubuntu/.config/matplotlib/matplotlibrc", line #3
#   (fname, cnt))
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %% [markdown]
# # Define functions

# %%
def jaccard_coef(y_true, y_pred):
    y_true_fl = K.clip(K.batch_flatten(y_true), 0., 1.)
    y_pred_fl = K.clip(K.batch_flatten(y_pred), 0., 1.)
    y_true_fl = K.cast(K.greater(y_true_fl, 0.5), 'float32')
    y_pred_fl = K.cast(K.greater(y_pred_fl, 0.5), 'float32')
    intersection = K.sum(y_true_fl * y_pred_fl, axis=1)
    union = K.sum(K.maximum(y_true_fl, y_pred_fl), axis=1)
    union = K.switch(K.equal(union, 0), K.ones_like(union), union)
    return K.mean(intersection / K.cast(union, 'float32'))

def jaccard_coef_loss(y_true, y_pred):
    return -jaccard_coef(y_true, y_pred)

def dice(y_true, y_pred):
    y_true_f = K.clip(K.batch_flatten(y_true), 0., 1.)
    y_pred_f = K.clip(K.batch_flatten(y_pred), 0., 1.)
    intersection = 2 * K.sum(y_true_f * y_pred_f, axis=1)
    union = K.sum(y_true_f * y_true_f, axis=1) + K.sum(y_pred_f * y_pred_f, axis=1)
    return K.mean(intersection / union)

def dice_coef(y_true, y_pred):
    y_true_f = K.cast(K.greater(y_true, 0.5), 'float32')
    y_pred_f = K.cast(K.greater(y_pred, 0.5), 'float32')
    return dice(y_true_f, y_pred_f)

def dice_loss(y_true, y_pred):
    smooth = 1.
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

def bce_dice_loss(y_true, y_pred):
    return binary_crossentropy(y_true, y_pred) + (1 - dice_loss(y_true, y_pred))

# %% [markdown]
# # Define models

# %%
def unet_down_one_block(inputs, num_filters):
    x = Conv2D(num_filters, (3, 3), padding='same')(inputs)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Conv2D(num_filters, (3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    return x

# %%
def unet_max_pool(inputs):
    x = MaxPooling2D((2, 2), strides=(2, 2))(inputs)
    return x

# %%
def unet_up_one_block(up_input, down_input, num_filters):
    x = UpSampling2D((2,2))(up_input)
    x = concatenate([down_input, x], axis=3)
    x = Conv2D(num_filters, (3,3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Conv2D(num_filters, (3,3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Conv2D(num_filters, (3,3), padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    return x

# %%
#### Formula to create model goes here ###

# %%
from keras.utils import plot_model  
plot_model(model, to_file='model-1024.png', show_shapes=True, show_layer_names=True)  
from IPython.display import FileLink
FileLink('model-1024.png')
# Out:
# /home/ubuntu/workspace/Fundus_UNET/model-1024.png

# %% [markdown]
# # Training

# %%
input_size = 1024
max_epochs = 50
threshold  = 0.5

# %%
df_train = pd.read_csv('data2/data/train_masks.csv')

# %%
df_train.head()
# Out:
#                img camera_short_name camera_long_name  counter  suspect eye  \
# 0  G-TPC0001-R.jpg               TPC           Topcon        1        1   R
# 1  G-TPC0002-L.jpg               TPC           Topcon        2        1   L
# 2  G-TPC0003-L.jpg               TPC           Topcon        3        1   L
# 3  G-TPC0004-R.jpg               TPC           Topcon        4        1   R
# 4  G-TPC0005-L.jpg               TPC           Topcon        5        1   L
#
#    height  width  areaDisc  saturationPixels  saturationLevel  scale  g  b  \
# 0    1934   1956     70095                 0                0   1081  1  1
# 1    1934   1956     58620                 0                0   1081  1  1
# 2    1934   1956     58703              1100                0   1081  1  1
# 3    1934   1956     59826                 0                0   1081  1  1
# 4    1934   1956     50247                 0                0   1081  1  1
#
#    factor      M   P      C
# 0  0.9985  64.52  18  62.85
# 1  0.9985  64.52  18  62.85
# 2  0.9985  64.52  18  62.85
# 3  0.9985  64.52  18  62.85
# 4  0.9985  64.52  18  62.85

# %%
ids_train = df_train['img'].map(lambda s: s.split('.')[0])

# %%
ids_train_split, ids_valid_split = train_test_split(ids_train, test_size=0.2, random_state=42)

# %%
def randomHueSaturationValue(image, hue_shift_limit=(-180, 180),
                             sat_shift_limit=(-255, 255),
                             val_shift_limit=(-255, 255), u=0.5):
    if np.random.random() < u:
        image = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
        h, s, v = cv2.split(image)
        hue_shift = np.random.uniform(hue_shift_limit[0], hue_shift_limit[1])
        h = cv2.add(h, hue_shift)
        sat_shift = np.random.uniform(sat_shift_limit[0], sat_shift_limit[1])
        s = cv2.add(s, sat_shift)
        val_shift = np.random.uniform(val_shift_limit[0], val_shift_limit[1])
        v = cv2.add(v, val_shift)
        image = cv2.merge((h, s, v))
        image = cv2.cvtColor(image, cv2.COLOR_HSV2BGR)

    return image

# %%
def randomShiftScaleRotate(image, mask,
                           shift_limit=(-0.0625, 0.0625),
                           scale_limit=(-0.1, 0.1),
                           rotate_limit=(-45, 45), aspect_limit=(0, 0),
                           borderMode=cv2.BORDER_CONSTANT, u=0.5):
    if np.random.random() < u:
        height, width, channel = image.shape

        angle = np.random.uniform(rotate_limit[0], rotate_limit[1])  # degree
        scale = np.random.uniform(1 + scale_limit[0], 1 + scale_limit[1])
        aspect = np.random.uniform(1 + aspect_limit[0], 1 + aspect_limit[1])
        sx = scale * aspect / (aspect ** 0.5)
        sy = scale / (aspect ** 0.5)
        dx = round(np.random.uniform(shift_limit[0], shift_limit[1]) * width)
        dy = round(np.random.uniform(shift_limit[0], shift_limit[1]) * height)

        cc = np.math.cos(angle / 180 * np.math.pi) * sx
        ss = np.math.sin(angle / 180 * np.math.pi) * sy
        rotate_matrix = np.array([[cc, -ss], [ss, cc]])

        box0 = np.array([[0, 0], [width, 0], [width, height], [0, height], ])
        box1 = box0 - np.array([width / 2, height / 2])
        box1 = np.dot(box1, rotate_matrix.T) + np.array([width / 2 + dx, height / 2 + dy])

        box0 = box0.astype(np.float32)
        box1 = box1.astype(np.float32)
        mat = cv2.getPerspectiveTransform(box0, box1)
        image = cv2.warpPerspective(image, mat, (width, height), flags=cv2.INTER_LINEAR, borderMode=borderMode,
                                    borderValue=(
                                        0, 0,
                                        0,))
        mask = cv2.warpPerspective(mask, mat, (width, height), flags=cv2.INTER_LINEAR, borderMode=borderMode,
                                   borderValue=(
                                       0, 0,
                                       0,))

    return image, mask

# %%
def randomHorizontalFlip(image, mask, u=0.5):
    if np.random.random() < u:
        image = cv2.flip(image, 1)
        mask = cv2.flip(mask, 1)

    return image, mask

# %%
all_imgs  = {}
all_masks = {}
for id in ids_train:
    img  = cv2.imread('data2/data/train/{}.jpg'.format(id))
    img  = cv2.resize(img, (input_size, input_size))
    mask = cv2.imread('data2/data/train_masks/{}_mask.png'.format(id), cv2.IMREAD_GRAYSCALE)
    mask = cv2.resize(mask, (input_size, input_size))
    all_imgs[id]  = img
    all_masks[id] = mask

# %%
import random

# %%
def train_generator(train_batch_size):
    while True:
        this_ids_train_split = random.sample(list(ids_train_split), len(ids_train_split))
        for start in range(0, len(ids_train_split), train_batch_size):
            x_batch = []
            y_batch = []
            end = min(start + train_batch_size, len(ids_train_split))
            ids_train_batch = this_ids_train_split[start:end]
            for id in ids_train_batch:
                img  = all_imgs[id]
                mask = all_masks[id]
                img = randomHueSaturationValue(img,
                                               hue_shift_limit=(-50, 50),
                                               sat_shift_limit=(-5, 5),
                                               val_shift_limit=(-15, 15))
                img, mask = randomShiftScaleRotate(img, mask,
                                                   shift_limit=(-0.0625, 0.0625),
                                                   scale_limit=(-0.1, 0.1),
                                                   rotate_limit=(-0, 0))
                img, mask = randomHorizontalFlip(img, mask)
                mask = np.expand_dims(mask, axis=2)
                x_batch.append(img)
                y_batch.append(mask)
            x_batch = np.array(x_batch, np.float32) / 255
            y_batch = np.array(y_batch, np.float32) / 255
            yield x_batch, y_batch

# %%
def valid_generator(val_batch_size):
    while True:
        for start in range(0, len(ids_valid_split), val_batch_size):
            x_batch = []
            y_batch = []
            end = min(start + val_batch_size, len(ids_valid_split))
            ids_valid_batch = ids_valid_split[start:end]
            for id in ids_valid_batch.values:
                img  = all_imgs[id]
                mask = all_masks[id]
                mask = np.expand_dims(mask, axis=2)
                x_batch.append(img)
                y_batch.append(mask)
            x_batch = np.array(x_batch, np.float32) / 255
            y_batch = np.array(y_batch, np.float32) / 255
            yield x_batch, y_batch

# %%
train_batch_size = 6
val_batch_size   = 16

# %%
callbacks = [EarlyStopping(monitor='val_dice_loss',
                           patience=8,
                           verbose=1,
                           min_delta=1e-4,
                           mode='max'),
             ReduceLROnPlateau(monitor='val_dice_loss',
                               factor=0.1,
                               patience=4,
                               verbose=1,
                               min_delta=1e-4,
                               mode='max'),
             ModelCheckpoint(monitor='val_dice_loss',
                             filepath='weights/best_weights_1024.hdf5',
                             save_best_only=True,
                             save_weights_only=True,
                             mode='max')]

history = model.fit_generator(generator=train_generator(train_batch_size),
                    steps_per_epoch=np.ceil(float(len(ids_train_split)) / float(train_batch_size)),
                    epochs=max_epochs,
                    verbose=2,
                    callbacks=callbacks,
                    validation_data=valid_generator(val_batch_size),
                    validation_steps=np.ceil(float(len(ids_valid_split)) / float(val_batch_size)))
# Out:
# Epoch 1/50
#  - 143s - loss: 1.6847 - dice_loss: 0.0395 - jaccard_coef: 0.0919 - dice_coef: 0.1494 - val_loss: 1.6461 - val_dice_loss: 0.0469 - val_jaccard_coef: 0.1055 - val_dice_coef: 0.1770
# Epoch 2/50
#  - 130s - loss: 1.5746 - dice_loss: 0.0464 - jaccard_coef: 0.3438 - dice_coef: 0.4830 - val_loss: 1.5867 - val_dice_loss: 0.0498 - val_jaccard_coef: 0.1758 - val_dice_coef: 0.2757
# Epoch 3/50
#  - 131s - loss: 1.5312 - dice_loss: 0.0506 - jaccard_coef: 0.5997 - dice_coef: 0.7368 - val_loss: 1.5095 - val_dice_loss: 0.0529 - val_jaccard_coef: 0.7221 - val_dice_coef: 0.8325
# Epoch 4/50
#  - 131s - loss: 1.5057 - dice_loss: 0.0533 - jaccard_coef: 0.7256 - dice_coef: 0.8316 - val_loss: 1.4787 - val_dice_loss: 0.0546 - val_jaccard_coef: 0.7612 - val_dice_coef: 0.8578
# Epoch 5/50
#  - 131s - loss: 1.4819 - dice_loss: 0.0556 - jaccard_coef: 0.7632 - dice_coef: 0.8587 - val_loss: 1.4537 - val_dice_loss: 0.0575 - val_jaccard_coef: 0.8089 - val_dice_coef: 0.8915
# Epoch 6/50
#  - 131s - loss: 1.4583 - dice_loss: 0.0580 - jaccard_coef: 0.7923 - dice_coef: 0.8778 - val_loss: 1.4415 - val_dice_loss: 0.0605 - val_jaccard_coef: 0.7512 - val_dice_coef: 0.8506
# Epoch 7/50
#  - 131s - loss: 1.4354 - dice_loss: 0.0602 - jaccard_coef: 0.8094 - dice_coef: 0.8887 - val_loss: 1.4118 - val_dice_loss: 0.0613 - val_jaccard_coef: 0.8147 - val_dice_coef: 0.8934
# Epoch 8/50
#  - 131s - loss: 1.4129 - dice_loss: 0.0623 - jaccard_coef: 0.8224 - dice_coef: 0.8967 - val_loss: 1.3946 - val_dice_loss: 0.0637 - val_jaccard_coef: 0.8301 - val_dice_coef: 0.9030
# Epoch 9/50
#  - 130s - loss: 1.3903 - dice_loss: 0.0647 - jaccard_coef: 0.8334 - dice_coef: 0.9046 - val_loss: 1.3657 - val_dice_loss: 0.0655 - val_jaccard_coef: 0.8721 - val_dice_coef: 0.9300
# Epoch 10/50
#  - 131s - loss: 1.3683 - dice_loss: 0.0669 - jaccard_coef: 0.8361 - dice_coef: 0.9069 - val_loss: 1.3462 - val_dice_loss: 0.0692 - val_jaccard_coef: 0.8596 - val_dice_coef: 0.9226
# Epoch 11/50
#  - 131s - loss: 1.3457 - dice_loss: 0.0699 - jaccard_coef: 0.8464 - dice_coef: 0.9134 - val_loss: 1.3164 - val_dice_loss: 0.0733 - val_jaccard_coef: 0.8508 - val_dice_coef: 0.9172
# Epoch 12/50
#  - 131s - loss: 1.3239 - dice_loss: 0.0725 - jaccard_coef: 0.8514 - dice_coef: 0.9169 - val_loss: 1.3037 - val_dice_loss: 0.0750 - val_jaccard_coef: 0.8499 - val_dice_coef: 0.9169
# Epoch 13/50
#  - 131s - loss: 1.3023 - dice_loss: 0.0754 - jaccard_coef: 0.8532 - dice_coef: 0.9178 - val_loss: 1.2779 - val_dice_loss: 0.0785 - val_jaccard_coef: 0.8779 - val_dice_coef: 0.9335
# Epoch 14/50
#  - 131s - loss: 1.2807 - dice_loss: 0.0787 - jaccard_coef: 0.8532 - dice_coef: 0.9167 - val_loss: 1.2519 - val_dice_loss: 0.0831 - val_jaccard_coef: 0.8607 - val_dice_coef: 0.9235
# Epoch 15/50
#  - 131s - loss: 1.2593 - dice_loss: 0.0821 - jaccard_coef: 0.8622 - dice_coef: 0.9240 - val_loss: 1.2279 - val_dice_loss: 0.0877 - val_jaccard_coef: 0.8574 - val_dice_coef: 0.9213
# Epoch 16/50
#  - 131s - loss: 1.2383 - dice_loss: 0.0857 - jaccard_coef: 0.8632 - dice_coef: 0.9245 - val_loss: 1.2166 - val_dice_loss: 0.0898 - val_jaccard_coef: 0.8644 - val_dice_coef: 0.9259
# Epoch 17/50
#  - 131s - loss: 1.2175 - dice_loss: 0.0895 - jaccard_coef: 0.8658 - dice_coef: 0.9259 - val_loss: 1.1976 - val_dice_loss: 0.0935 - val_jaccard_coef: 0.8622 - val_dice_coef: 0.9239
# Epoch 18/50
#  - 131s - loss: 1.1967 - dice_loss: 0.0939 - jaccard_coef: 0.8675 - dice_coef: 0.9273 - val_loss: 1.1770 - val_dice_loss: 0.0980 - val_jaccard_coef: 0.8718 - val_dice_coef: 0.9301
# Epoch 19/50
#  - 131s - loss: 1.1766 - dice_loss: 0.0982 - jaccard_coef: 0.8700 - dice_coef: 0.9284 - val_loss: 1.1416 - val_dice_loss: 0.1067 - val_jaccard_coef: 0.8694 - val_dice_coef: 0.9289
# Epoch 20/50
#  - 131s - loss: 1.1566 - dice_loss: 0.1029 - jaccard_coef: 0.8683 - dice_coef: 0.9272 - val_loss: 1.1298 - val_dice_loss: 0.1102 - val_jaccard_coef: 0.8724 - val_dice_coef: 0.9307
# Epoch 21/50
#  - 131s - loss: 1.1362 - dice_loss: 0.1084 - jaccard_coef: 0.8723 - dice_coef: 0.9299 - val_loss: 1.0970 - val_dice_loss: 0.1194 - val_jaccard_coef: 0.8690 - val_dice_coef: 0.9286
# Epoch 22/50
#  - 131s - loss: 1.1168 - dice_loss: 0.1137 - jaccard_coef: 0.8736 - dice_coef: 0.9312 - val_loss: 1.0966 - val_dice_loss: 0.1195 - val_jaccard_coef: 0.8813 - val_dice_coef: 0.9360
# Epoch 23/50
#  - 131s - loss: 1.0971 - dice_loss: 0.1196 - jaccard_coef: 0.8742 - dice_coef: 0.9317 - val_loss: 1.0874 - val_dice_loss: 0.1219 - val_jaccard_coef: 0.8914 - val_dice_coef: 0.9416
# Epoch 24/50
#  - 131s - loss: 1.0776 - dice_loss: 0.1261 - jaccard_coef: 0.8726 - dice_coef: 0.9305 - val_loss: 1.0365 - val_dice_loss: 0.1409 - val_jaccard_coef: 0.8636 - val_dice_coef: 0.9254
# Epoch 25/50
#  - 131s - loss: 1.0583 - dice_loss: 0.1329 - jaccard_coef: 0.8747 - dice_coef: 0.9319 - val_loss: 1.0280 - val_dice_loss: 0.1452 - val_jaccard_coef: 0.8598 - val_dice_coef: 0.9232
# Epoch 26/50
#  - 131s - loss: 1.0394 - dice_loss: 0.1398 - jaccard_coef: 0.8756 - dice_coef: 0.9324 - val_loss: 1.0069 - val_dice_loss: 0.1524 - val_jaccard_coef: 0.8810 - val_dice_coef: 0.9358
# Epoch 27/50
#  - 131s - loss: 1.0202 - dice_loss: 0.1477 - jaccard_coef: 0.8738 - dice_coef: 0.9307 - val_loss: 0.9999 - val_dice_loss: 0.1554 - val_jaccard_coef: 0.8915 - val_dice_coef: 0.9417
# Epoch 28/50
#  - 131s - loss: 1.0008 - dice_loss: 0.1560 - jaccard_coef: 0.8779 - dice_coef: 0.9339 - val_loss: 1.0076 - val_dice_loss: 0.1542 - val_jaccard_coef: 0.8735 - val_dice_coef: 0.9313
# Epoch 29/50
#  - 131s - loss: 0.9822 - dice_loss: 0.1643 - jaccard_coef: 0.8778 - dice_coef: 0.9335 - val_loss: 0.9653 - val_dice_loss: 0.1715 - val_jaccard_coef: 0.8780 - val_dice_coef: 0.9325
# Epoch 30/50
#  - 131s - loss: 0.9630 - dice_loss: 0.1737 - jaccard_coef: 0.8773 - dice_coef: 0.9326 - val_loss: 0.9126 - val_dice_loss: 0.2015 - val_jaccard_coef: 0.8643 - val_dice_coef: 0.9254
# Epoch 31/50
#  - 131s - loss: 0.9437 - dice_loss: 0.1837 - jaccard_coef: 0.8798 - dice_coef: 0.9350 - val_loss: 0.9406 - val_dice_loss: 0.1866 - val_jaccard_coef: 0.8751 - val_dice_coef: 0.9324
# Epoch 32/50
#  - 131s - loss: 0.9241 - dice_loss: 0.1946 - jaccard_coef: 0.8782 - dice_coef: 0.9337 - val_loss: 0.9296 - val_dice_loss: 0.1930 - val_jaccard_coef: 0.8707 - val_dice_coef: 0.9292
# Epoch 33/50
#  - 131s - loss: 0.9041 - dice_loss: 0.2061 - jaccard_coef: 0.8825 - dice_coef: 0.9366 - val_loss: 0.8478 - val_dice_loss: 0.2407 - val_jaccard_coef: 0.8842 - val_dice_coef: 0.9374
# Epoch 34/50
#  - 131s - loss: 0.8838 - dice_loss: 0.2186 - jaccard_coef: 0.8807 - dice_coef: 0.9351 - val_loss: 0.8228 - val_dice_loss: 0.2569 - val_jaccard_coef: 0.8714 - val_dice_coef: 0.9292
# Epoch 35/50
#  - 131s - loss: 0.8643 - dice_loss: 0.2307 - jaccard_coef: 0.8796 - dice_coef: 0.9344 - val_loss: 0.8916 - val_dice_loss: 0.2137 - val_jaccard_coef: 0.8958 - val_dice_coef: 0.9441
# Epoch 36/50
#  - 131s - loss: 0.8431 - dice_loss: 0.2450 - jaccard_coef: 0.8824 - dice_coef: 0.9360 - val_loss: 0.7932 - val_dice_loss: 0.2789 - val_jaccard_coef: 0.8845 - val_dice_coef: 0.9376
# Epoch 37/50
#  - 131s - loss: 0.8228 - dice_loss: 0.2587 - jaccard_coef: 0.8841 - dice_coef: 0.9373 - val_loss: 0.8106 - val_dice_loss: 0.2678 - val_jaccard_coef: 0.8866 - val_dice_coef: 0.9387
# Epoch 38/50
#  - 131s - loss: 0.8012 - dice_loss: 0.2741 - jaccard_coef: 0.8856 - dice_coef: 0.9383 - val_loss: 0.7831 - val_dice_loss: 0.2875 - val_jaccard_coef: 0.8810 - val_dice_coef: 0.9355
# Epoch 39/50
#  - 131s - loss: 0.7789 - dice_loss: 0.2906 - jaccard_coef: 0.8871 - dice_coef: 0.9390 - val_loss: 0.7463 - val_dice_loss: 0.3153 - val_jaccard_coef: 0.8823 - val_dice_coef: 0.9358
# Epoch 40/50
#  - 131s - loss: 0.7473 - dice_loss: 0.3150 - jaccard_coef: 0.8897 - dice_coef: 0.9407 - val_loss: 0.6589 - val_dice_loss: 0.3881 - val_jaccard_coef: 0.8742 - val_dice_coef: 0.9314
# Epoch 41/50
#  - 131s - loss: 0.6896 - dice_loss: 0.3602 - jaccard_coef: 0.8907 - dice_coef: 0.9412 - val_loss: 0.6486 - val_dice_loss: 0.3938 - val_jaccard_coef: 0.8956 - val_dice_coef: 0.9440
# Epoch 42/50
#  - 131s - loss: 0.6604 - dice_loss: 0.3844 - jaccard_coef: 0.8932 - dice_coef: 0.9425 - val_loss: 0.6195 - val_dice_loss: 0.4202 - val_jaccard_coef: 0.8723 - val_dice_coef: 0.9304
# Epoch 43/50
#  - 131s - loss: 0.5984 - dice_loss: 0.4383 - jaccard_coef: 0.8968 - dice_coef: 0.9446 - val_loss: 0.6166 - val_dice_loss: 0.4207 - val_jaccard_coef: 0.9009 - val_dice_coef: 0.9470
# Epoch 44/50
#  - 131s - loss: 0.5180 - dice_loss: 0.5098 - jaccard_coef: 0.8979 - dice_coef: 0.9447 - val_loss: 0.5212 - val_dice_loss: 0.5059 - val_jaccard_coef: 0.9027 - val_dice_coef: 0.9478
# Epoch 45/50
#  - 131s - loss: 0.4843 - dice_loss: 0.5405 - jaccard_coef: 0.8995 - dice_coef: 0.9460 - val_loss: 0.4659 - val_dice_loss: 0.5570 - val_jaccard_coef: 0.8942 - val_dice_coef: 0.9420
# Epoch 46/50
#  - 131s - loss: 0.4522 - dice_loss: 0.5701 - jaccard_coef: 0.9027 - dice_coef: 0.9482 - val_loss: 0.4324 - val_dice_loss: 0.5887 - val_jaccard_coef: 0.8956 - val_dice_coef: 0.9437
# Epoch 47/50
#  - 131s - loss: 0.4213 - dice_loss: 0.5987 - jaccard_coef: 0.9050 - dice_coef: 0.9488 - val_loss: 0.4017 - val_dice_loss: 0.6177 - val_jaccard_coef: 0.8922 - val_dice_coef: 0.9421
# Epoch 48/50
#  - 131s - loss: 0.3933 - dice_loss: 0.6250 - jaccard_coef: 0.9056 - dice_coef: 0.9489 - val_loss: 0.3722 - val_dice_loss: 0.6453 - val_jaccard_coef: 0.8961 - val_dice_coef: 0.9428
# Epoch 49/50
#  - 131s - loss: 0.3633 - dice_loss: 0.6532 - jaccard_coef: 0.9086 - dice_coef: 0.9515 - val_loss: 0.3534 - val_dice_loss: 0.6622 - val_jaccard_coef: 0.9000 - val_dice_coef: 0.9452
# Epoch 50/50
#  - 131s - loss: 0.3344 - dice_loss: 0.6806 - jaccard_coef: 0.9099 - dice_coef: 0.9519 - val_loss: 0.3188 - val_dice_loss: 0.6957 - val_jaccard_coef: 0.9044 - val_dice_coef: 0.9491

# %%
history.history
# Out:
# {'val_loss': [1.6461490646998087,
#   1.5866867113113403,
#   1.5095243978500366,
#   1.478719210624695,
#   1.4537429126103718,
#   1.4415287669499715,
#   1.4118183835347493,
#   1.394555811882019,
#   1.3656678501764934,
#   1.3461950476964315,
#   1.3163682381312052,
#   1.303739488919576,
#   1.2779382117589315,
#   1.2519352738062541,
#   1.2279066451390583,
e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04,
#   1e-04]}

# %%
plt.plot(history.history['jaccard_coef'])
plt.plot(history.history['dice_coef'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Jaccard Index', 'Dice Coefficient'], loc='upper left')
plt.show()

# %%
model.load_weights('./weights/best_weights_1024.hdf5')

# %%
 model.compile(optimizer=RMSprop(lr=0.00001),
                  loss=bce_dice_loss,
                  metrics=[dice_loss, jaccard_coef, dice_coef])

# %%
max_epochs = 10

# %%
callbacks = [EarlyStopping(monitor='val_dice_loss',
                           patience=8,
                           verbose=1,
                           min_delta=1e-4,
                           mode='max'),
             ReduceLROnPlateau(monitor='val_dice_loss',
                               factor=0.1,
                               patience=4,
                               verbose=1,
                               min_delta=1e-4,
                               mode='max'),
             ModelCheckpoint(monitor='val_dice_loss',
                             filepath='weights/best_weights_1024_2.hdf5',
                             save_best_only=True,
                             save_weights_only=True,
                             mode='max')]

history = model.fit_generator(generator=train_generator(train_batch_size),
                    steps_per_epoch=np.ceil(float(len(ids_train_split)) / float(train_batch_size)),
                    epochs=max_epochs,
                    verbose=2,
                    callbacks=callbacks,
                    validation_data=valid_generator(val_batch_size),
                    validation_steps=np.ceil(float(len(ids_valid_split)) / float(val_batch_size)))
# Out:
# Epoch 1/10
#  - 137s - loss: 0.3163 - dice_loss: 0.6974 - jaccard_coef: 0.9191 - dice_coef: 0.9574 - val_loss: 0.3177 - val_dice_loss: 0.6966 - val_jaccard_coef: 0.9067 - val_dice_coef: 0.9505
# Epoch 2/10
#  - 131s - loss: 0.3129 - dice_loss: 0.7007 - jaccard_coef: 0.9189 - dice_coef: 0.9572 - val_loss: 0.3159 - val_dice_loss: 0.6982 - val_jaccard_coef: 0.9077 - val_dice_coef: 0.9511
# Epoch 3/10
#  - 131s - loss: 0.3106 - dice_loss: 0.7028 - jaccard_coef: 0.9192 - dice_coef: 0.9567 - val_loss: 0.3129 - val_dice_loss: 0.7011 - val_jaccard_coef: 0.9083 - val_dice_coef: 0.9514
# Epoch 4/10
#  - 131s - loss: 0.3080 - dice_loss: 0.7053 - jaccard_coef: 0.9188 - dice_coef: 0.9568 - val_loss: 0.3107 - val_dice_loss: 0.7032 - val_jaccard_coef: 0.9093 - val_dice_coef: 0.9519
# Epoch 5/10
#  - 131s - loss: 0.3051 - dice_loss: 0.7081 - jaccard_coef: 0.9205 - dice_coef: 0.9574 - val_loss: 0.3076 - val_dice_loss: 0.7063 - val_jaccard_coef: 0.9063 - val_dice_coef: 0.9502
# Epoch 6/10
#  - 131s - loss: 0.3018 - dice_loss: 0.7112 - jaccard_coef: 0.9214 - dice_coef: 0.9587 - val_loss: 0.3058 - val_dice_loss: 0.7079 - val_jaccard_coef: 0.9084 - val_dice_coef: 0.9515
# Epoch 7/10
#  - 131s - loss: 0.2987 - dice_loss: 0.7141 - jaccard_coef: 0.9239 - dice_coef: 0.9601 - val_loss: 0.3038 - val_dice_loss: 0.7098 - val_jaccard_coef: 0.9083 - val_dice_coef: 0.9514
# Epoch 8/10
#  - 131s - loss: 0.2966 - dice_loss: 0.7161 - jaccard_coef: 0.9217 - dice_coef: 0.9585 - val_loss: 0.3008 - val_dice_loss: 0.7126 - val_jaccard_coef: 0.9079 - val_dice_coef: 0.9511
# Epoch 9/10
#  - 131s - loss: 0.2938 - dice_loss: 0.7188 - jaccard_coef: 0.9224 - dice_coef: 0.9588 - val_loss: 0.2981 - val_dice_loss: 0.7151 - val_jaccard_coef: 0.9103 - val_dice_coef: 0.9525
# Epoch 10/10
#  - 131s - loss: 0.2909 - dice_loss: 0.7216 - jaccard_coef: 0.9226 - dice_coef: 0.9589 - val_loss: 0.2957 - val_dice_loss: 0.7175 - val_jaccard_coef: 0.9095 - val_dice_coef: 0.9521

# %%
history.history
# Out:
# {'val_loss': [0.31773381074269613,
#   0.31593114256858823,
#   0.31291214426358543,
#   0.31071420311927794,
#   0.3075726866722107,
#   0.30577508012453714,
#   0.30381782690684,
#   0.3008371790250142,
#   0.29808884143829345,
#   0.29574326912562054],
#  'val_dice_loss': [0.6965910593668619,
#   0.6982210810979207,
#   0.701086303393046,
#   0.7031768814722696,
#   0.7063394991556803,
#   0.7079131031036376,
#   0.7098465434710185,
#   0.7126435017585755,
#   0.7151180402437846,
#   0.717481419245402],
#  'val_jaccard_coef': [0.9066631388664246,
#   0.9077476620674133,
#   0.9083283615112304,
#   0.9092882696787516,
#   0.9063322106997173,
#   0.9084340310096741,
#   0.9083274134000142,
#   0.9078629390398661,
#   0.9102677210172018,
#   0.9095426885286967],
#  'val_dice_coef': [0.950513166586558,
#   0.9510868326822917,
#   0.9514279754956564,
#   0.9519480681419372,
#   0.9501830156644185,
#   0.9514601143201192,
#   0.9514400895436604,
#   0.95112562417984,
#   0.9524898338317871,
#   0.9521151804924011],
#  'loss': [0.316347296833992,
#   0.31285779997706414,
#   0.310643550157547,
#   0.30801338128745553,
#   0.30506959013640883,
#   0.30182759135961534,
#   0.2986532452702522,
#   0.29660668469965457,
#   0.29378124706447123,
#   0.29088582172989846],
#  'dice_loss': [0.6973677605390549,
#   0.7007287940382958,
#   0.7027990362048149,
#   0.7053473204374313,
#   0.7081136563420296,
#   0.7111816200613975,
#   0.7140768930315972,
#   0.7161426120996475,
#   0.7187776750326157,
#   0.7215947803854942],
#  'jaccard_coef': [0.9190622559189796,
#   0.9188884201645852,
#   0.9192332226037979,
#   0.9188424202799798,
#   0.920519660115242,
#   0.9214288142323493,
#   0.923890061378479,
#   0.921684487760067,
#   0.9223660719394684,
#   0.922600202858448],
#  'dice_coef': [0.9574040979146957,
#   0.9572321560978889,
#   0.9567059773206711,
#   0.9568285402655602,
#   0.9573871472477913,
#   0.958668509721756,
#   0.9600552973151207,
#   0.9584714028239251,
#   0.9588307505846023,
#   0.9589025625586509],
#  'lr': [1e-05, 1e-05, 1e-05, 1e-05, 1e-05, 1e-05, 1e-05, 1e-05, 1e-05, 1e-05]}

# %%
plt.plot(history.history['jaccard_coef'])
plt.plot(history.history['dice_coef'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Jaccard Index', 'Dice Coefficient'], loc='upper left')
plt.show()

# %% [markdown]
# # Predictions

# %%
from tqdm import tqdm

# %%
df_test = pd.read_csv('data2/data/test.csv')
ids_test = df_test['img'].map(lambda s: s.split('.')[0])

# %%
names = []
for id in ids_test:
    names.append('{}.jpg'.format(id))

# %%
model.load_weights(filepath='weights/best_weights_1024_2.hdf5')

# %%
val_batch_size = 1

# %%
import matplotlib.pyplot as plt

print('Predicting on {} samples with batch_size = {}...'.format(len(ids_test), val_batch_size))
for start in tqdm(range(0, len(ids_test), val_batch_size)):
    x_batch = []
    end = min(start + val_batch_size, len(ids_test))
    ids_test_batch = ids_test[start:end]
    for id in ids_test_batch.values:
        img = cv2.imread('data2/data/test/test/{}.jpg'.format(id))
        orig_width = np.shape(img)[1]
        orig_height = np.shape(img)[0]
        img = cv2.resize(img, (input_size, input_size))
        x_batch.append(img)
    x_batch = np.array(x_batch, np.float32) / 255
    preds = model.predict_on_batch(x_batch)
    for pred in preds:
        prob = cv2.resize(pred, (orig_width, orig_height))
        mask = prob > threshold
        mask = mask*255
        fig = plt.figure()
        ax = fig.add_subplot(1, 1, 1)
        ax.imshow(mask)
        plt.show()
        cv2.imwrite('data2/data/DL_masks1024/{}.png'.format(id),mask)
# Out:
#   0%|          | 0/265 [00:00<?, ?it/s]
# Predicting on 265 samples with batch_size = 1...
#   0%|          | 1/265 [00:01<06:33,  1.49s/it]
#   1%|          | 2/265 [00:01<04:05,  1.07it/s]
#   1%|          | 3/265 [00:02<03:16,  1.34it/s]
#   2%|▏         | 4/265 [00:02<02:51,  1.53it/s]
#   2%|▏         | 5/265 [00:03<02:36,  1.66it/s]
#   2%|▏         | 6/265 [00:03<02:26,  1.77it/s]
#   3%|▎         | 7/265 [00:03<02:18,  1.86it/s]
#   3%|▎         | 8/265 [00:04<02:13,  1.93it/s]
#   3%|▎         | 9/265 [00:04<02:08,  1.99it/s]
#   4%|▍         | 10/265 [00:04<02:05,  2.04it/s]
#   4%|▍         | 11/265 [00:05<02:02,  2.08it/s]
#   5%|▍         | 12/265 [00:05<01:59,  2.12it/s]
#   5%|▍         | 13/265 [00:06<01:56,  2.15it/s]
#   5%|▌         | 14/265 [00:06<01:55,  2.18it/s]
#   6%|▌         | 15/265 [00:06<01:53,  2.21it/s]
#   6%|▌         | 16/265 [00:07<01:51,  2.23it/s]
#   6%|▋         | 17/265 [00:07<01:50,  2.25it/s]
#   7%|▋         | 18/265 [00:07<01:49,  2.27it/s]
#   7%|▋         | 19/265 [00:08<01:47,  2.28it/s]
#   8%|▊         | 20/265 [00:08<01:46,  2.30it/s]
#   8%|▊         | 21/265 [00:09<01:45,  2.31it/s]
#   8%|▊         | 22/265 [00:09<01:44,  2.32it/s]
#   9%|▊         | 23/265 [00:09<01:43,  2.34it/s]
#   9%|▉         | 24/265 [00:10<01:42,  2.35it/s]
#   9%|▉         | 25/265 [00:10<01:41,  2.36it/s]
#  10%|▉         | 26/265 [00:10<01:40,  2.37it/s]
#  10%|█         | 27/265 [00:11<01:40,  2.38it/s]
#  11%|█         | 28/265 [00:11<01:39,  2.38it/s]
#  11%|█         | 29/265 [00:12<01:38,  2.39it/s]
#  11%|█▏        | 30/265 [00:12<01:38,  2.39it/s]
#  12%|█▏        | 31/265 [00:12<01:37,  2.40it/s]
#  12%|█▏        | 32/265 [00:13<01:36,  2.41it/s]
